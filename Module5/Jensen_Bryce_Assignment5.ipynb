# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %% [markdown]
# # Original
#
# Solved in 37 runs, 137 total runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 20
# Scores: (min: 20, avg: 20, max: 20)
#
# Run: 2, exploration: 0.9369146928798039, score: 14
# Scores: (min: 14, avg: 17, max: 20)
#
# Run: 3, exploration: 0.798065677681905, score: 33
# Scores: (min: 14, avg: 22.333333333333332, max: 33)
#
# Run: 4, exploration: 0.7147372386831305, score: 23
# Scores: (min: 14, avg: 22.5, max: 33)
#
# Run: 5, exploration: 0.6696478204705644, score: 14
# Scores: (min: 14, avg: 20.8, max: 33)
#
# Run: 6, exploration: 0.6369088258938781, score: 11
# Scores: (min: 11, avg: 19.166666666666668, max: 33)
#
# Run: 7, exploration: 0.5997278763867329, score: 13
# Scores: (min: 11, avg: 18.285714285714285, max: 33)
#
# Run: 8, exploration: 0.5704072587541458, score: 11
# Scores: (min: 11, avg: 17.375, max: 33)
#
# Run: 9, exploration: 0.5264466124450268, score: 17
# Scores: (min: 11, avg: 17.333333333333332, max: 33)
#
# Run: 10, exploration: 0.46444185833082485, score: 26
# Scores: (min: 11, avg: 18.2, max: 33)
#
# Run: 11, exploration: 0.42437208406280985, score: 19
# Scores: (min: 11, avg: 18.272727272727273, max: 33)
#
# Run: 12, exploration: 0.36880183088056995, score: 29
# Scores: (min: 11, avg: 19.166666666666668, max: 33)
#
# Run: 13, exploration: 0.2519690537792925, score: 77
# Scores: (min: 11, avg: 23.615384615384617, max: 77)
#
# Run: 14, exploration: 0.1800916657318127, score: 68
# Scores: (min: 11, avg: 26.785714285714285, max: 77)
#
# Run: 15, exploration: 0.1580861105294992, score: 27
# Scores: (min: 11, avg: 26.8, max: 77)
#
# Run: 16, exploration: 0.14372497725712216, score: 20
# Scores: (min: 11, avg: 26.375, max: 77)
#
# Run: 17, exploration: 0.13001512070402377, score: 21
# Scores: (min: 11, avg: 26.058823529411764, max: 77)
#
# Run: 18, exploration: 0.1085487359239089, score: 37
# Scores: (min: 11, avg: 26.666666666666668, max: 77)
#
# Run: 19, exploration: 0.09108200798387568, score: 36
# Scores: (min: 11, avg: 27.157894736842106, max: 77)
#
# Run: 20, exploration: 0.08406242000238873, score: 17
# Scores: (min: 11, avg: 26.65, max: 77)
#
# Run: 21, exploration: 0.0716045256805401, score: 33
# Scores: (min: 11, avg: 26.952380952380953, max: 77)
#
# Run: 22, exploration: 0.06477420436570952, score: 21
# Scores: (min: 11, avg: 26.681818181818183, max: 77)
#
# Run: 23, exploration: 0.05772088009124167, score: 24
# Scores: (min: 11, avg: 26.565217391304348, max: 77)
#
# Run: 24, exploration: 0.04146257532741124, score: 67
# Scores: (min: 11, avg: 28.25, max: 77)
#
# Run: 25, exploration: 0.03325613897196732, score: 45
# Scores: (min: 11, avg: 28.92, max: 77)
#
# Run: 26, exploration: 0.0280450728002803, score: 35
# Scores: (min: 11, avg: 29.153846153846153, max: 77)
#
# Run: 27, exploration: 0.024250791254731636, score: 30
# Scores: (min: 11, avg: 29.185185185185187, max: 77)
#
# Run: 28, exploration: 0.020864997436994256, score: 31
# Scores: (min: 11, avg: 29.25, max: 77)
#
# Run: 29, exploration: 0.01607750060057119, score: 53
# Scores: (min: 11, avg: 30.06896551724138, max: 77)
#
# Run: 30, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 33.43333333333333, max: 131)
#
# Run: 31, exploration: 0.01, score: 56
# Scores: (min: 11, avg: 34.16129032258065, max: 131)
#
# Run: 32, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 34.125, max: 131)
#
# Run: 33, exploration: 0.01, score: 45
# Scores: (min: 11, avg: 34.45454545454545, max: 131)
#
# Run: 34, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 34.23529411764706, max: 131)
#
# Run: 35, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 34.285714285714285, max: 131)
#
# Run: 36, exploration: 0.01, score: 40
# Scores: (min: 11, avg: 34.44444444444444, max: 131)
#
# Run: 37, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 35.21621621621622, max: 131)
#
# Run: 38, exploration: 0.01, score: 70
# Scores: (min: 11, avg: 36.13157894736842, max: 131)
#
# Run: 39, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 36.743589743589745, max: 131)
#
# Run: 40, exploration: 0.01, score: 34
# Scores: (min: 11, avg: 36.675, max: 131)
#
# Run: 41, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 37.46341463414634, max: 131)
#
# Run: 42, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 39, max: 131)
#
# Run: 43, exploration: 0.01, score: 87
# Scores: (min: 11, avg: 40.116279069767444, max: 131)
#
# Run: 44, exploration: 0.01, score: 78
# Scores: (min: 11, avg: 40.97727272727273, max: 131)
#
# Run: 45, exploration: 0.01, score: 78
# Scores: (min: 11, avg: 41.8, max: 131)
#
# Run: 46, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 43.02173913043478, max: 131)
#
# Run: 47, exploration: 0.01, score: 55
# Scores: (min: 11, avg: 43.276595744680854, max: 131)
#
# Run: 48, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 44.708333333333336, max: 131)
#
# Run: 49, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 45.36734693877551, max: 131)
#
# Run: 50, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 45.84, max: 131)
#
# Run: 51, exploration: 0.01, score: 90
# Scores: (min: 11, avg: 46.705882352941174, max: 131)
#
# Run: 52, exploration: 0.01, score: 109
# Scores: (min: 11, avg: 47.90384615384615, max: 131)
#
# Run: 53, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 49.62264150943396, max: 139)
#
# Run: 54, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 50.98148148148148, max: 139)
#
# Run: 55, exploration: 0.01, score: 245
# Scores: (min: 11, avg: 54.50909090909091, max: 245)
#
# Run: 56, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 55.80357142857143, max: 245)
#
# Run: 57, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 57.719298245614034, max: 245)
#
# Run: 58, exploration: 0.01, score: 181
# Scores: (min: 11, avg: 59.8448275862069, max: 245)
#
# Run: 59, exploration: 0.01, score: 267
# Scores: (min: 11, avg: 63.355932203389834, max: 267)
#
# Run: 60, exploration: 0.01, score: 196
# Scores: (min: 11, avg: 65.56666666666666, max: 267)
#
# Run: 61, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 67.29508196721312, max: 267)
#
# Run: 62, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 66.37096774193549, max: 267)
#
# Run: 63, exploration: 0.01, score: 250
# Scores: (min: 10, avg: 69.28571428571429, max: 267)
#
# Run: 64, exploration: 0.01, score: 231
# Scores: (min: 10, avg: 71.8125, max: 267)
#
# Run: 65, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 73.66153846153846, max: 267)
#
# Run: 66, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 75.31818181818181, max: 267)
#
# Run: 67, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 76.86567164179104, max: 267)
#
# Run: 68, exploration: 0.01, score: 277
# Scores: (min: 10, avg: 79.80882352941177, max: 277)
#
# Run: 69, exploration: 0.01, score: 323
# Scores: (min: 10, avg: 83.33333333333333, max: 323)
#
# Run: 70, exploration: 0.01, score: 250
# Scores: (min: 10, avg: 85.71428571428571, max: 323)
#
# Run: 71, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 86.95774647887323, max: 323)
#
# Run: 72, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 88.65277777777777, max: 323)
#
# Run: 73, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 90.04109589041096, max: 323)
#
# Run: 74, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 91.28378378378379, max: 323)
#
# Run: 75, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 92.88, max: 323)
#
# Run: 76, exploration: 0.01, score: 338
# Scores: (min: 10, avg: 96.10526315789474, max: 338)
#
# Run: 77, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 96.81818181818181, max: 338)
#
# Run: 78, exploration: 0.01, score: 229
# Scores: (min: 10, avg: 98.51282051282051, max: 338)
#
# Run: 79, exploration: 0.01, score: 257
# Scores: (min: 10, avg: 100.51898734177215, max: 338)
#
# Run: 80, exploration: 0.01, score: 339
# Scores: (min: 10, avg: 103.5, max: 339)
#
# Run: 81, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 104.27160493827161, max: 339)
#
# Run: 82, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 105.86585365853658, max: 339)
#
# Run: 83, exploration: 0.01, score: 474
# Scores: (min: 10, avg: 110.3012048192771, max: 474)
#
# Run: 84, exploration: 0.01, score: 263
# Scores: (min: 10, avg: 112.11904761904762, max: 474)
#
# Run: 85, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 113.04705882352941, max: 474)
#
# Run: 86, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 114.06976744186046, max: 474)
#
# Run: 87, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 114.50574712643679, max: 474)
#
# Run: 88, exploration: 0.01, score: 338
# Scores: (min: 10, avg: 117.04545454545455, max: 474)
# Run: 89, exploration: 0.01, score: 290
# Scores: (min: 10, avg: 118.98876404494382, max: 474)
#
# Run: 90, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 120.13333333333334, max: 474)
#
# Run: 91, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 124.3076923076923, max: 500)
#
# Run: 92, exploration: 0.01, score: 441
# Scores: (min: 10, avg: 127.75, max: 500)
#
# Run: 93, exploration: 0.01, score: 251
# Scores: (min: 10, avg: 129.0752688172043, max: 500)
#
# Run: 94, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 129.5744680851064, max: 500)
#
# Run: 95, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 130.16842105263157, max: 500)
#
# Run: 96, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 131.34375, max: 500)
#
# Run: 97, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 131.68041237113403, max: 500)
#
# Run: 98, exploration: 0.01, score: 321
# Scores: (min: 10, avg: 133.6122448979592, max: 500)
#
# Run: 99, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 133.83838383838383, max: 500)
#
# Run: 100, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 133.9, max: 500)
#
# Run: 101, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 134.96, max: 500)
#
# Run: 102, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 136.31, max: 500)
#
# Run: 103, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 137.27, max: 500)
#
# Run: 104, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 138.38, max: 500)
#
# Run: 105, exploration: 0.01, score: 195
# Scores: (min: 10, avg: 140.19, max: 500)
#
# Run: 106, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 142.32, max: 500)
#
# Run: 107, exploration: 0.01, score: 241
# Scores: (min: 10, avg: 144.6, max: 500)
#
# Run: 108, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 146.12, max: 500)
#
# Run: 109, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 147.19, max: 500)
#
# Run: 110, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 148.71, max: 500)
#
# Run: 111, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 150.08, max: 500)
#
# Run: 112, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 151.17, max: 500)
#
# Run: 113, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 152.5, max: 500)
#
# Run: 114, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 153.24, max: 500)
#
# Run: 115, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 154.56, max: 500)
#
# Run: 116, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 155.83, max: 500)
#
# Run: 117, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 157.01, max: 500)
#
# Run: 118, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 157.96, max: 500)
#
# Run: 119, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 159.39, max: 500)
#
# Run: 120, exploration: 0.01, score: 446
# Scores: (min: 10, avg: 163.68, max: 500)
#
# Run: 121, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 165.12, max: 500)
#
# Run: 122, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 166.44, max: 500)
#
# Run: 123, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 168, max: 500)
#
# Run: 124, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 168.77, max: 500)
#
# Run: 125, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 170.05, max: 500)
#
# Run: 126, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 171.38, max: 500)
#
# Run: 127, exploration: 0.01, score: 232
# Scores: (min: 10, avg: 173.4, max: 500)
#
# Run: 128, exploration: 0.01, score: 255
# Scores: (min: 10, avg: 175.64, max: 500)
#
# Run: 129, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 177.21, max: 500)
#
# Run: 130, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 177.77, max: 500)
#
# Run: 131, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 178.83, max: 500)
#
# Run: 132, exploration: 0.01, score: 241
# Scores: (min: 10, avg: 180.91, max: 500)
#
# Run: 133, exploration: 0.01, score: 300
# Scores: (min: 10, avg: 183.46, max: 500)
#
# Run: 134, exploration: 0.01, score: 312
# Scores: (min: 10, avg: 186.31, max: 500)
#
# Run: 135, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 188.05, max: 500)
#
# Run: 136, exploration: 0.01, score: 309
# Scores: (min: 10, avg: 190.74, max: 500)
#
# Run: 137, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 195.11, max: 500)
#
# Solved in 37 runs, 137 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# # Exploration Factor Changed
#
#     EXPLORATION_MAX: 1.0 --> 0.5
#
#     EXPLORATION_MIN: 0.01 --> 0.1
#
# Solved in 201 runs, 301 total runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.5  
EXPLORATION_MIN = 0.1  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()  

cartpole()
# Out:
# Run: 1, exploration: 0.47794478917877986, score: 29
# Scores: (min: 29, avg: 29, max: 29)
#
# Run: 2, exploration: 0.43671004801269353, score: 19
# Scores: (min: 19, avg: 24, max: 29)
#
# Run: 3, exploration: 0.39505248627351397, score: 21
# Scores: (min: 19, avg: 23, max: 29)
#
# Run: 4, exploration: 0.3609692879892581, score: 19
# Scores: (min: 19, avg: 22, max: 29)
#
# Run: 5, exploration: 0.33650644244751976, score: 15
# Scores: (min: 15, avg: 20.6, max: 29)
#
# Run: 6, exploration: 0.3121329338217698, score: 16
# Scores: (min: 15, avg: 19.833333333333332, max: 29)
#
# Run: 7, exploration: 0.29244193182929556, score: 14
# Scores: (min: 14, avg: 19, max: 29)
#
# Run: 8, exploration: 0.2809469295581664, score: 9
# Scores: (min: 9, avg: 17.75, max: 29)
#
# Run: 9, exploration: 0.2516124151989211, score: 23
# Scores: (min: 9, avg: 18.333333333333332, max: 29)
#
# Run: 10, exploration: 0.23222092916541243, score: 17
# Scores: (min: 9, avg: 18.2, max: 29)
#
# Run: 11, exploration: 0.21540092780399553, score: 16
# Scores: (min: 9, avg: 18, max: 29)
#
# Run: 12, exploration: 0.20384565452337597, score: 12
# Scores: (min: 9, avg: 17.5, max: 29)
#
# Run: 13, exploration: 0.11339708875992931, score: 118
# Scores: (min: 9, avg: 25.23076923076923, max: 118)
#
# Run: 14, exploration: 0.1, score: 38
# Scores: (min: 9, avg: 26.142857142857142, max: 118)
#
# Run: 15, exploration: 0.1, score: 39
# Scores: (min: 9, avg: 27, max: 118)
#
# Run: 16, exploration: 0.1, score: 39
# Scores: (min: 9, avg: 27.75, max: 118)
#
# Run: 17, exploration: 0.1, score: 23
# Scores: (min: 9, avg: 27.470588235294116, max: 118)
#
# Run: 18, exploration: 0.1, score: 31
# Scores: (min: 9, avg: 27.666666666666668, max: 118)
#
# Run: 19, exploration: 0.1, score: 53
# Scores: (min: 9, avg: 29, max: 118)
#
# Run: 20, exploration: 0.1, score: 77
# Scores: (min: 9, avg: 31.4, max: 118)
#
# Run: 21, exploration: 0.1, score: 30
# Scores: (min: 9, avg: 31.333333333333332, max: 118)
#
# Run: 22, exploration: 0.1, score: 41
# Scores: (min: 9, avg: 31.772727272727273, max: 118)
#
# Run: 23, exploration: 0.1, score: 13
# Scores: (min: 9, avg: 30.956521739130434, max: 118)
#
# Run: 24, exploration: 0.1, score: 21
# Scores: (min: 9, avg: 30.541666666666668, max: 118)
#
# Run: 25, exploration: 0.1, score: 39
# Scores: (min: 9, avg: 30.88, max: 118)
#
# Run: 26, exploration: 0.1, score: 55
# Scores: (min: 9, avg: 31.807692307692307, max: 118)
#
# Run: 27, exploration: 0.1, score: 60
# Scores: (min: 9, avg: 32.851851851851855, max: 118)
#
# Run: 28, exploration: 0.1, score: 14
# Scores: (min: 9, avg: 32.17857142857143, max: 118)
#
# Run: 29, exploration: 0.1, score: 11
# Scores: (min: 9, avg: 31.448275862068964, max: 118)
#
# Run: 30, exploration: 0.1, score: 72
# Scores: (min: 9, avg: 32.8, max: 118)
#
# Run: 31, exploration: 0.1, score: 14
# Scores: (min: 9, avg: 32.193548387096776, max: 118)
#
# Run: 32, exploration: 0.1, score: 66
# Scores: (min: 9, avg: 33.25, max: 118)
#
# Run: 33, exploration: 0.1, score: 80
# Scores: (min: 9, avg: 34.666666666666664, max: 118)
#
# Run: 34, exploration: 0.1, score: 111
# Scores: (min: 9, avg: 36.911764705882355, max: 118)
#
# Run: 35, exploration: 0.1, score: 127
# Scores: (min: 9, avg: 39.48571428571429, max: 127)
#
# Run: 36, exploration: 0.1, score: 140
# Scores: (min: 9, avg: 42.27777777777778, max: 140)
#
# Run: 37, exploration: 0.1, score: 197
# Scores: (min: 9, avg: 46.45945945945946, max: 197)
#
# Run: 38, exploration: 0.1, score: 192
# Scores: (min: 9, avg: 50.28947368421053, max: 197)
#
# Run: 39, exploration: 0.1, score: 233
# Scores: (min: 9, avg: 54.97435897435897, max: 233)
#
# Run: 40, exploration: 0.1, score: 180
# Scores: (min: 9, avg: 58.1, max: 233)
#
# Run: 41, exploration: 0.1, score: 202
# Scores: (min: 9, avg: 61.609756097560975, max: 233)
#
# Run: 42, exploration: 0.1, score: 178
# Scores: (min: 9, avg: 64.38095238095238, max: 233)
#
# Run: 43, exploration: 0.1, score: 189
# Scores: (min: 9, avg: 67.27906976744185, max: 233)
#
# Run: 44, exploration: 0.1, score: 191
# Scores: (min: 9, avg: 70.0909090909091, max: 233)
#
# Run: 45, exploration: 0.1, score: 196
# Scores: (min: 9, avg: 72.88888888888889, max: 233)
#
# Run: 46, exploration: 0.1, score: 187
# Scores: (min: 9, avg: 75.3695652173913, max: 233)
#
# Run: 47, exploration: 0.1, score: 191
# Scores: (min: 9, avg: 77.82978723404256, max: 233)
#
# Run: 48, exploration: 0.1, score: 184
# Scores: (min: 9, avg: 80.04166666666667, max: 233)
#
# Run: 49, exploration: 0.1, score: 175
# Scores: (min: 9, avg: 81.9795918367347, max: 233)
#
# Run: 50, exploration: 0.1, score: 234
# Scores: (min: 9, avg: 85.02, max: 234)
#
# Run: 51, exploration: 0.1, score: 168
# Scores: (min: 9, avg: 86.6470588235294, max: 234)
#
# Run: 52, exploration: 0.1, score: 180
# Scores: (min: 9, avg: 88.4423076923077, max: 234)
#
# Run: 53, exploration: 0.1, score: 212
# Scores: (min: 9, avg: 90.77358490566037, max: 234)
#
# Run: 54, exploration: 0.1, score: 194
# Scores: (min: 9, avg: 92.68518518518519, max: 234)
#
# Run: 55, exploration: 0.1, score: 199
# Scores: (min: 9, avg: 94.61818181818182, max: 234)
#
# Run: 56, exploration: 0.1, score: 196
# Scores: (min: 9, avg: 96.42857142857143, max: 234)
#
# Run: 57, exploration: 0.1, score: 192
# Scores: (min: 9, avg: 98.10526315789474, max: 234)
#
# Run: 58, exploration: 0.1, score: 201
# Scores: (min: 9, avg: 99.87931034482759, max: 234)
#
# Run: 59, exploration: 0.1, score: 204
# Scores: (min: 9, avg: 101.64406779661017, max: 234)
#
# Run: 60, exploration: 0.1, score: 237
# Scores: (min: 9, avg: 103.9, max: 237)
#
# Run: 61, exploration: 0.1, score: 177
# Scores: (min: 9, avg: 105.09836065573771, max: 237)
#
# Run: 62, exploration: 0.1, score: 173
# Scores: (min: 9, avg: 106.19354838709677, max: 237)
#
# Run: 63, exploration: 0.1, score: 216
# Scores: (min: 9, avg: 107.93650793650794, max: 237)
#
# Run: 64, exploration: 0.1, score: 226
# Scores: (min: 9, avg: 109.78125, max: 237)
#
# Run: 65, exploration: 0.1, score: 180
# Scores: (min: 9, avg: 110.86153846153846, max: 237)
#
# Run: 66, exploration: 0.1, score: 178
# Scores: (min: 9, avg: 111.87878787878788, max: 237)
#
# Run: 67, exploration: 0.1, score: 228
# Scores: (min: 9, avg: 113.61194029850746, max: 237)
#
# Run: 68, exploration: 0.1, score: 177
# Scores: (min: 9, avg: 114.54411764705883, max: 237)
#
# Run: 69, exploration: 0.1, score: 185
# Scores: (min: 9, avg: 115.56521739130434, max: 237)
#
# Run: 70, exploration: 0.1, score: 218
# Scores: (min: 9, avg: 117.02857142857142, max: 237)
#
# Run: 71, exploration: 0.1, score: 180
# Scores: (min: 9, avg: 117.91549295774648, max: 237)
#
# Run: 72, exploration: 0.1, score: 187
# Scores: (min: 9, avg: 118.875, max: 237)
#
# Run: 73, exploration: 0.1, score: 186
# Scores: (min: 9, avg: 119.79452054794521, max: 237)
#
# Run: 74, exploration: 0.1, score: 210
# Scores: (min: 9, avg: 121.01351351351352, max: 237)
#
# Run: 75, exploration: 0.1, score: 201
# Scores: (min: 9, avg: 122.08, max: 237)
#
# Run: 76, exploration: 0.1, score: 172
# Scores: (min: 9, avg: 122.73684210526316, max: 237)
#
# Run: 77, exploration: 0.1, score: 206
# Scores: (min: 9, avg: 123.81818181818181, max: 237)
#
# Run: 78, exploration: 0.1, score: 189
# Scores: (min: 9, avg: 124.65384615384616, max: 237)
#
# Run: 79, exploration: 0.1, score: 178
# Scores: (min: 9, avg: 125.32911392405063, max: 237)
#
# Run: 80, exploration: 0.1, score: 208
# Scores: (min: 9, avg: 126.3625, max: 237)
#
# Run: 81, exploration: 0.1, score: 192
# Scores: (min: 9, avg: 127.17283950617283, max: 237)
#
# Run: 82, exploration: 0.1, score: 262
# Scores: (min: 9, avg: 128.8170731707317, max: 262)
#
# Run: 83, exploration: 0.1, score: 169
# Scores: (min: 9, avg: 129.3012048192771, max: 262)
#
# Run: 84, exploration: 0.1, score: 247
# Scores: (min: 9, avg: 130.70238095238096, max: 262)
#
# Run: 85, exploration: 0.1, score: 16
# Scores: (min: 9, avg: 129.35294117647058, max: 262)
#
# Run: 86, exploration: 0.1, score: 146
# Scores: (min: 9, avg: 129.54651162790697, max: 262)
#
# Run: 87, exploration: 0.1, score: 206
# Scores: (min: 9, avg: 130.42528735632183, max: 262)
#
# Run: 88, exploration: 0.1, score: 238
# Scores: (min: 9, avg: 131.64772727272728, max: 262)
#
# Run: 89, exploration: 0.1, score: 211
# Scores: (min: 9, avg: 132.53932584269663, max: 262)
#
# Run: 90, exploration: 0.1, score: 204
# Scores: (min: 9, avg: 133.33333333333334, max: 262)
#
# Run: 91, exploration: 0.1, score: 180
# Scores: (min: 9, avg: 133.84615384615384, max: 262)
#
# Run: 92, exploration: 0.1, score: 161
# Scores: (min: 9, avg: 134.1413043478261, max: 262)
#
# Run: 93, exploration: 0.1, score: 296
# Scores: (min: 9, avg: 135.88172043010752, max: 296)
# Run: 94, exploration: 0.1, score: 200
# Scores: (min: 9, avg: 136.56382978723406, max: 296)
#
# Run: 95, exploration: 0.1, score: 160
# Scores: (min: 9, avg: 136.81052631578947, max: 296)
#
# Run: 96, exploration: 0.1, score: 170
# Scores: (min: 9, avg: 137.15625, max: 296)
#
# Run: 97, exploration: 0.1, score: 51
# Scores: (min: 9, avg: 136.2680412371134, max: 296)
#
# Run: 98, exploration: 0.1, score: 14
# Scores: (min: 9, avg: 135.0204081632653, max: 296)
#
# Run: 99, exploration: 0.1, score: 299
# Scores: (min: 9, avg: 136.67676767676767, max: 299)
#
# Run: 100, exploration: 0.1, score: 170
# Scores: (min: 9, avg: 137.01, max: 299)
#
# Run: 101, exploration: 0.1, score: 173
# Scores: (min: 9, avg: 138.45, max: 299)
#
# Run: 102, exploration: 0.1, score: 79
# Scores: (min: 9, avg: 139.05, max: 299)
#
# Run: 103, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 138.93, max: 299)
#
# Run: 104, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 138.84, max: 299)
#
# Run: 105, exploration: 0.1, score: 11
# Scores: (min: 9, avg: 138.8, max: 299)
#
# Run: 106, exploration: 0.1, score: 11
# Scores: (min: 9, avg: 138.75, max: 299)
#
# Run: 107, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 138.71, max: 299)
#
# Run: 108, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 138.71, max: 299)
#
# Run: 109, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 138.57, max: 299)
#
# Run: 110, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 138.5, max: 299)
#
# Run: 111, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 138.43, max: 299)
#
# Run: 112, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 138.4, max: 299)
#
# Run: 113, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 137.32, max: 299)
#
# Run: 114, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 137.03, max: 299)
#
# Run: 115, exploration: 0.1, score: 10
# Scores: (min: 9, avg: 136.74, max: 299)
#
# Run: 116, exploration: 0.1, score: 12
# Scores: (min: 9, avg: 136.47, max: 299)
#
# Run: 117, exploration: 0.1, score: 213
# Scores: (min: 9, avg: 138.37, max: 299)
#
# Run: 118, exploration: 0.1, score: 225
# Scores: (min: 9, avg: 140.31, max: 299)
#
# Run: 119, exploration: 0.1, score: 187
# Scores: (min: 9, avg: 141.65, max: 299)
#
# Run: 120, exploration: 0.1, score: 168
# Scores: (min: 9, avg: 142.56, max: 299)
#
# Run: 121, exploration: 0.1, score: 190
# Scores: (min: 9, avg: 144.16, max: 299)
#
# Run: 122, exploration: 0.1, score: 170
# Scores: (min: 9, avg: 145.45, max: 299)
#
# Run: 123, exploration: 0.1, score: 361
# Scores: (min: 9, avg: 148.93, max: 361)
#
# Run: 124, exploration: 0.1, score: 166
# Scores: (min: 9, avg: 150.38, max: 361)
#
# Run: 125, exploration: 0.1, score: 276
# Scores: (min: 9, avg: 152.75, max: 361)
#
# Run: 126, exploration: 0.1, score: 178
# Scores: (min: 9, avg: 153.98, max: 361)
#
# Run: 127, exploration: 0.1, score: 141
# Scores: (min: 9, avg: 154.79, max: 361)
#
# Run: 128, exploration: 0.1, score: 148
# Scores: (min: 9, avg: 156.13, max: 361)
#
# Run: 129, exploration: 0.1, score: 223
# Scores: (min: 9, avg: 158.25, max: 361)
#
# Run: 130, exploration: 0.1, score: 285
# Scores: (min: 9, avg: 160.38, max: 361)
#
# Run: 131, exploration: 0.1, score: 260
# Scores: (min: 9, avg: 162.84, max: 361)
#
# Run: 132, exploration: 0.1, score: 184
# Scores: (min: 9, avg: 164.02, max: 361)
#
# Run: 133, exploration: 0.1, score: 156
# Scores: (min: 9, avg: 164.78, max: 361)
#
# Run: 134, exploration: 0.1, score: 240
# Scores: (min: 9, avg: 166.07, max: 361)
#
# Run: 135, exploration: 0.1, score: 194
# Scores: (min: 9, avg: 166.74, max: 361)
#
# Run: 136, exploration: 0.1, score: 181
# Scores: (min: 9, avg: 167.15, max: 361)
#
# Run: 137, exploration: 0.1, score: 203
# Scores: (min: 9, avg: 167.21, max: 361)
#
# Run: 138, exploration: 0.1, score: 356
# Scores: (min: 9, avg: 168.85, max: 361)
#
# Run: 139, exploration: 0.1, score: 220
# Scores: (min: 9, avg: 168.72, max: 361)
#
# Run: 140, exploration: 0.1, score: 281
# Scores: (min: 9, avg: 169.73, max: 361)
#
# Run: 141, exploration: 0.1, score: 190
# Scores: (min: 9, avg: 169.61, max: 361)
#
# Run: 142, exploration: 0.1, score: 258
# Scores: (min: 9, avg: 170.41, max: 361)
#
# Run: 143, exploration: 0.1, score: 290
# Scores: (min: 9, avg: 171.42, max: 361)
#
# Run: 144, exploration: 0.1, score: 14
# Scores: (min: 9, avg: 169.65, max: 361)
#
# Run: 145, exploration: 0.1, score: 9
# Scores: (min: 9, avg: 167.78, max: 361)
#
# Run: 146, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 165.99, max: 361)
#
# Run: 147, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 164.21, max: 361)
#
# Run: 148, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 162.46, max: 361)
#
# Run: 149, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 160.81, max: 361)
#
# Run: 150, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 158.58, max: 361)
#
# Run: 151, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 157, max: 361)
#
# Run: 152, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 155.29, max: 361)
#
# Run: 153, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 153.27, max: 361)
#
# Run: 154, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 151.42, max: 361)
#
# Run: 155, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 149.52, max: 361)
#
# Run: 156, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 147.65, max: 361)
#
# Run: 157, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 145.83, max: 361)
#
# Run: 158, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 143.91, max: 361)
#
# Run: 159, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 141.98, max: 361)
#
# Run: 160, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 139.7, max: 361)
#
# Run: 161, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 138.03, max: 361)
#
# Run: 162, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 136.41, max: 361)
#
# Run: 163, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 134.34, max: 361)
#
# Run: 164, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 132.19, max: 361)
#
# Run: 165, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 130.49, max: 361)
#
# Run: 166, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 128.8, max: 361)
#
# Run: 167, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 126.61, max: 361)
#
# Run: 168, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 124.95, max: 361)
#
# Run: 169, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 123.19, max: 361)
#
# Run: 170, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 121.09, max: 361)
#
# Run: 171, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 119.38, max: 361)
#
# Run: 172, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 117.61, max: 361)
#
# Run: 173, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 115.85, max: 361)
#
# Run: 174, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 113.86, max: 361)
#
# Run: 175, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 111.95, max: 361)
#
# Run: 176, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 110.34, max: 361)
#
# Run: 177, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 108.38, max: 361)
#
# Run: 178, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 106.62, max: 361)
#
# Run: 179, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 104.92, max: 361)
#
# Run: 180, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 102.93, max: 361)
#
# Run: 181, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 101.11, max: 361)
#
# Run: 182, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 98.6, max: 361)
#
# Run: 183, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 97, max: 361)
#
# Run: 184, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 94.63, max: 361)
#
# Run: 185, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 94.56, max: 361)
#
# Run: 186, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 93.19, max: 361)
#
# Run: 187, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 91.22, max: 361)
#
# Run: 188, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 88.94, max: 361)
#
# Run: 189, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 86.95, max: 361)
#
# Run: 190, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 85, max: 361)
#
# Run: 191, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 83.29, max: 361)
#
# Run: 192, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 81.77, max: 361)
#
# Run: 193, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 78.9, max: 361)
#
# Run: 194, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 77, max: 361)
#
# Run: 195, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 75.5, max: 361)
#
# Run: 196, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 73.91, max: 361)
#
# Run: 197, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 73.51, max: 361)
# Run: 198, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 73.46, max: 361)
#
# Run: 199, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 70.58, max: 361)
#
# Run: 200, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 68.97, max: 361)
#
# Run: 201, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 67.33, max: 361)
#
# Run: 202, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 66.63, max: 361)
#
# Run: 203, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 66.63, max: 361)
#
# Run: 204, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 66.64, max: 361)
#
# Run: 205, exploration: 0.1, score: 12
# Scores: (min: 8, avg: 66.65, max: 361)
#
# Run: 206, exploration: 0.1, score: 54
# Scores: (min: 8, avg: 67.08, max: 361)
#
# Run: 207, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 67.06, max: 361)
#
# Run: 208, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 67.07, max: 361)
#
# Run: 209, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 67.08, max: 361)
#
# Run: 210, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 67.07, max: 361)
#
# Run: 211, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 67.08, max: 361)
#
# Run: 212, exploration: 0.1, score: 9
# Scores: (min: 8, avg: 67.08, max: 361)
#
# Run: 213, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 67.08, max: 361)
#
# Run: 214, exploration: 0.1, score: 8
# Scores: (min: 8, avg: 67.07, max: 361)
#
# Run: 215, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 67.07, max: 361)
#
# Run: 216, exploration: 0.1, score: 10
# Scores: (min: 8, avg: 67.05, max: 361)
#
# Run: 217, exploration: 0.1, score: 126
# Scores: (min: 8, avg: 66.18, max: 361)
#
# Run: 218, exploration: 0.1, score: 139
# Scores: (min: 8, avg: 65.32, max: 361)
#
# Run: 219, exploration: 0.1, score: 101
# Scores: (min: 8, avg: 64.46, max: 361)
#
# Run: 220, exploration: 0.1, score: 11
# Scores: (min: 8, avg: 62.89, max: 361)
#
# Run: 221, exploration: 0.1, score: 13
# Scores: (min: 8, avg: 61.12, max: 361)
#
# Run: 222, exploration: 0.1, score: 132
# Scores: (min: 8, avg: 60.74, max: 361)
#
# Run: 223, exploration: 0.1, score: 202
# Scores: (min: 8, avg: 59.15, max: 356)
#
# Run: 224, exploration: 0.1, score: 210
# Scores: (min: 8, avg: 59.59, max: 356)
#
# Run: 225, exploration: 0.1, score: 254
# Scores: (min: 8, avg: 59.37, max: 356)
#
# Run: 226, exploration: 0.1, score: 271
# Scores: (min: 8, avg: 60.3, max: 356)
#
# Run: 227, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 59.57, max: 356)
#
# Run: 228, exploration: 0.1, score: 175
# Scores: (min: 8, avg: 59.84, max: 356)
#
# Run: 229, exploration: 0.1, score: 81
# Scores: (min: 8, avg: 58.42, max: 356)
#
# Run: 230, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 56.07, max: 356)
#
# Run: 231, exploration: 0.1, score: 115
# Scores: (min: 8, avg: 54.62, max: 356)
#
# Run: 232, exploration: 0.1, score: 104
# Scores: (min: 8, avg: 53.82, max: 356)
#
# Run: 233, exploration: 0.1, score: 51
# Scores: (min: 8, avg: 52.77, max: 356)
#
# Run: 234, exploration: 0.1, score: 66
# Scores: (min: 8, avg: 51.03, max: 356)
#
# Run: 235, exploration: 0.1, score: 150
# Scores: (min: 8, avg: 50.59, max: 356)
#
# Run: 236, exploration: 0.1, score: 24
# Scores: (min: 8, avg: 49.02, max: 356)
#
# Run: 237, exploration: 0.1, score: 49
# Scores: (min: 8, avg: 47.48, max: 356)
#
# Run: 238, exploration: 0.1, score: 30
# Scores: (min: 8, avg: 44.22, max: 290)
#
# Run: 239, exploration: 0.1, score: 47
# Scores: (min: 8, avg: 42.49, max: 290)
#
# Run: 240, exploration: 0.1, score: 19
# Scores: (min: 8, avg: 39.87, max: 290)
#
# Run: 241, exploration: 0.1, score: 29
# Scores: (min: 8, avg: 38.26, max: 290)
#
# Run: 242, exploration: 0.1, score: 47
# Scores: (min: 8, avg: 36.15, max: 290)
#
# Run: 243, exploration: 0.1, score: 114
# Scores: (min: 8, avg: 34.39, max: 271)
#
# Run: 244, exploration: 0.1, score: 91
# Scores: (min: 8, avg: 35.16, max: 271)
#
# Run: 245, exploration: 0.1, score: 236
# Scores: (min: 8, avg: 37.43, max: 271)
#
# Run: 246, exploration: 0.1, score: 68
# Scores: (min: 8, avg: 38.03, max: 271)
#
# Run: 247, exploration: 0.1, score: 76
# Scores: (min: 8, avg: 38.66, max: 271)
#
# Run: 248, exploration: 0.1, score: 47
# Scores: (min: 8, avg: 39.04, max: 271)
#
# Run: 249, exploration: 0.1, score: 65
# Scores: (min: 8, avg: 39.59, max: 271)
#
# Run: 250, exploration: 0.1, score: 50
# Scores: (min: 8, avg: 39.98, max: 271)
#
# Run: 251, exploration: 0.1, score: 92
# Scores: (min: 8, avg: 40.8, max: 271)
#
# Run: 252, exploration: 0.1, score: 162
# Scores: (min: 8, avg: 42.33, max: 271)
#
# Run: 253, exploration: 0.1, score: 114
# Scores: (min: 8, avg: 43.37, max: 271)
#
# Run: 254, exploration: 0.1, score: 213
# Scores: (min: 8, avg: 45.41, max: 271)
#
# Run: 255, exploration: 0.1, score: 399
# Scores: (min: 8, avg: 49.31, max: 399)
#
# Run: 256, exploration: 0.1, score: 148
# Scores: (min: 8, avg: 50.7, max: 399)
#
# Run: 257, exploration: 0.1, score: 333
# Scores: (min: 8, avg: 53.93, max: 399)
#
# Run: 258, exploration: 0.1, score: 371
# Scores: (min: 8, avg: 57.55, max: 399)
#
# Run: 259, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 62.44, max: 500)
#
# Run: 260, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 67.35, max: 500)
#
# Run: 261, exploration: 0.1, score: 46
# Scores: (min: 8, avg: 67.71, max: 500)
#
# Run: 262, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 72.6, max: 500)
#
# Run: 263, exploration: 0.1, score: 325
# Scores: (min: 8, avg: 75.76, max: 500)
#
# Run: 264, exploration: 0.1, score: 466
# Scores: (min: 8, avg: 80.31, max: 500)
#
# Run: 265, exploration: 0.1, score: 373
# Scores: (min: 8, avg: 83.94, max: 500)
#
# Run: 266, exploration: 0.1, score: 186
# Scores: (min: 8, avg: 85.71, max: 500)
#
# Run: 267, exploration: 0.1, score: 254
# Scores: (min: 8, avg: 88.16, max: 500)
#
# Run: 268, exploration: 0.1, score: 341
# Scores: (min: 8, avg: 91.46, max: 500)
#
# Run: 269, exploration: 0.1, score: 237
# Scores: (min: 8, avg: 93.74, max: 500)
#
# Run: 270, exploration: 0.1, score: 326
# Scores: (min: 8, avg: 96.92, max: 500)
#
# Run: 271, exploration: 0.1, score: 354
# Scores: (min: 8, avg: 100.37, max: 500)
#
# Run: 272, exploration: 0.1, score: 277
# Scores: (min: 8, avg: 103.04, max: 500)
#
# Run: 273, exploration: 0.1, score: 317
# Scores: (min: 8, avg: 106.11, max: 500)
#
# Run: 274, exploration: 0.1, score: 268
# Scores: (min: 8, avg: 108.68, max: 500)
#
# Run: 275, exploration: 0.1, score: 327
# Scores: (min: 8, avg: 111.85, max: 500)
#
# Run: 276, exploration: 0.1, score: 215
# Scores: (min: 8, avg: 113.89, max: 500)
#
# Run: 277, exploration: 0.1, score: 481
# Scores: (min: 8, avg: 118.6, max: 500)
#
# Run: 278, exploration: 0.1, score: 322
# Scores: (min: 8, avg: 121.69, max: 500)
#
# Run: 279, exploration: 0.1, score: 340
# Scores: (min: 8, avg: 125.01, max: 500)
#
# Run: 280, exploration: 0.1, score: 229
# Scores: (min: 8, avg: 127.21, max: 500)
#
# Run: 281, exploration: 0.1, score: 273
# Scores: (min: 8, avg: 129.84, max: 500)
#
# Run: 282, exploration: 0.1, score: 234
# Scores: (min: 8, avg: 132.07, max: 500)
#
# Run: 283, exploration: 0.1, score: 375
# Scores: (min: 8, avg: 135.73, max: 500)
#
# Run: 284, exploration: 0.1, score: 322
# Scores: (min: 8, avg: 138.85, max: 500)
#
# Run: 285, exploration: 0.1, score: 241
# Scores: (min: 8, avg: 141.17, max: 500)
#
# Run: 286, exploration: 0.1, score: 368
# Scores: (min: 8, avg: 144.76, max: 500)
#
# Run: 287, exploration: 0.1, score: 296
# Scores: (min: 8, avg: 147.63, max: 500)
#
# Run: 288, exploration: 0.1, score: 317
# Scores: (min: 8, avg: 150.7, max: 500)
#
# Run: 289, exploration: 0.1, score: 392
# Scores: (min: 8, avg: 154.5, max: 500)
#
# Run: 290, exploration: 0.1, score: 374
# Scores: (min: 8, avg: 158.15, max: 500)
#
# Run: 291, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 163.06, max: 500)
#
# Run: 292, exploration: 0.1, score: 223
# Scores: (min: 8, avg: 165.2, max: 500)
#
# Run: 293, exploration: 0.1, score: 269
# Scores: (min: 8, avg: 167.8, max: 500)
#
# Run: 294, exploration: 0.1, score: 496
# Scores: (min: 8, avg: 172.66, max: 500)
#
# Run: 295, exploration: 0.1, score: 338
# Scores: (min: 8, avg: 175.94, max: 500)
#
# Run: 296, exploration: 0.1, score: 257
# Scores: (min: 8, avg: 178.4, max: 500)
#
# Run: 297, exploration: 0.1, score: 500
# Scores: (min: 8, avg: 183.29, max: 500)
#
# Run: 298, exploration: 0.1, score: 376
# Scores: (min: 8, avg: 186.96, max: 500)
#
# Run: 299, exploration: 0.1, score: 216
# Scores: (min: 8, avg: 189.01, max: 500)
#
# Run: 300, exploration: 0.1, score: 277
# Scores: (min: 8, avg: 191.69, max: 500)
#
# Run: 301, exploration: 0.1, score: 424
# Scores: (min: 8, avg: 195.84, max: 500)
#
# Solved in 201 runs, 301 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7cd562026142> in <module>
#      88             dqn_solver.experience_replay()
#      89
# ---> 90 cartpole()
#
# <ipython-input-6-7cd562026142> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # Learning Rate changed
#
#     LEARNING_RATE: 0.001 --> 0.0001
#
# Solved in 366 runs, 466 total runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.0001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()  

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.946354579813443, score: 15
# Scores: (min: 15, avg: 15.5, max: 16)
#
# Run: 3, exploration: 0.8348931673187264, score: 26
# Scores: (min: 15, avg: 19, max: 26)
#
# Run: 4, exploration: 0.7402609576967045, score: 25
# Scores: (min: 15, avg: 20.5, max: 26)
#
# Run: 5, exploration: 0.697046600835495, score: 13
# Scores: (min: 13, avg: 19, max: 26)
#
# Run: 6, exploration: 0.6401093727576664, score: 18
# Scores: (min: 13, avg: 18.833333333333332, max: 26)
#
# Run: 7, exploration: 0.5790496471185967, score: 21
# Scores: (min: 13, avg: 19.142857142857142, max: 26)
#
# Run: 8, exploration: 0.5290920728090721, score: 19
# Scores: (min: 13, avg: 19.125, max: 26)
#
# Run: 9, exploration: 0.4982051627146237, score: 13
# Scores: (min: 13, avg: 18.444444444444443, max: 26)
#
# Run: 10, exploration: 0.46211964903917074, score: 16
# Scores: (min: 13, avg: 18.2, max: 26)
#
# Run: 11, exploration: 0.42650460709830135, score: 17
# Scores: (min: 13, avg: 18.09090909090909, max: 26)
#
# Run: 12, exploration: 0.40769130904675194, score: 10
# Scores: (min: 10, avg: 17.416666666666668, max: 26)
#
# Run: 13, exploration: 0.3877593341372176, score: 11
# Scores: (min: 10, avg: 16.923076923076923, max: 26)
#
# Run: 14, exploration: 0.3706551064126331, score: 10
# Scores: (min: 10, avg: 16.428571428571427, max: 26)
#
# Run: 15, exploration: 0.3543053533848483, score: 10
# Scores: (min: 10, avg: 16, max: 26)
#
# Run: 16, exploration: 0.33362200135903064, score: 13
# Scores: (min: 10, avg: 15.8125, max: 26)
#
# Run: 17, exploration: 0.32050833588933575, score: 9
# Scores: (min: 9, avg: 15.411764705882353, max: 26)
#
# Run: 18, exploration: 0.3063705780533402, score: 10
# Scores: (min: 9, avg: 15.11111111111111, max: 26)
#
# Run: 19, exploration: 0.2913921604631864, score: 11
# Scores: (min: 9, avg: 14.894736842105264, max: 26)
#
# Run: 20, exploration: 0.27164454854530906, score: 15
# Scores: (min: 9, avg: 14.9, max: 26)
#
# Run: 21, exploration: 0.2583638820072446, score: 11
# Scores: (min: 9, avg: 14.714285714285714, max: 26)
#
# Run: 22, exploration: 0.24450384299593592, score: 12
# Scores: (min: 9, avg: 14.590909090909092, max: 26)
#
# Run: 23, exploration: 0.2178795886667409, score: 24
# Scores: (min: 9, avg: 15, max: 26)
#
# Run: 24, exploration: 0.2010878536592394, score: 17
# Scores: (min: 9, avg: 15.083333333333334, max: 26)
#
# Run: 25, exploration: 0.17919120740315364, score: 24
# Scores: (min: 9, avg: 15.44, max: 26)
#
# Run: 26, exploration: 0.16455423674261854, score: 18
# Scores: (min: 9, avg: 15.538461538461538, max: 26)
#
# Run: 27, exploration: 0.1518722266715875, score: 17
# Scores: (min: 9, avg: 15.592592592592593, max: 26)
#
# Run: 28, exploration: 0.14372497725712216, score: 12
# Scores: (min: 9, avg: 15.464285714285714, max: 26)
#
# Run: 29, exploration: 0.12181307688414106, score: 34
# Scores: (min: 9, avg: 16.103448275862068, max: 34)
#
# Run: 30, exploration: 0.10272559337455119, score: 35
# Scores: (min: 9, avg: 16.733333333333334, max: 35)
#
# Run: 31, exploration: 0.09017346495423652, score: 27
# Scores: (min: 9, avg: 17.06451612903226, max: 35)
#
# Run: 32, exploration: 0.0708902705368767, score: 49
# Scores: (min: 9, avg: 18.0625, max: 49)
#
# Run: 33, exploration: 0.05918580250061433, score: 37
# Scores: (min: 9, avg: 18.636363636363637, max: 49)
#
# Run: 34, exploration: 0.05380914294022049, score: 20
# Scores: (min: 9, avg: 18.676470588235293, max: 49)
#
# Run: 35, exploration: 0.05143559895690903, score: 10
# Scores: (min: 9, avg: 18.428571428571427, max: 49)
#
# Run: 36, exploration: 0.048190768399801194, score: 14
# Scores: (min: 9, avg: 18.305555555555557, max: 49)
#
# Run: 37, exploration: 0.046065053286412784, score: 10
# Scores: (min: 9, avg: 18.08108108108108, max: 49)
#
# Run: 38, exploration: 0.04359387414694703, score: 12
# Scores: (min: 9, avg: 17.92105263157895, max: 49)
#
# Run: 39, exploration: 0.041670929977297724, score: 10
# Scores: (min: 9, avg: 17.71794871794872, max: 49)
#
# Run: 40, exploration: 0.03983280768576652, score: 10
# Scores: (min: 9, avg: 17.525, max: 49)
#
# Run: 41, exploration: 0.03826710124979409, score: 9
# Scores: (min: 9, avg: 17.317073170731707, max: 49)
#
# Run: 42, exploration: 0.035673744367776934, score: 15
# Scores: (min: 9, avg: 17.261904761904763, max: 49)
#
# Run: 43, exploration: 0.03392965965983891, score: 11
# Scores: (min: 9, avg: 17.11627906976744, max: 49)
#
# Run: 44, exploration: 0.03275978694079333, score: 8
# Scores: (min: 8, avg: 16.90909090909091, max: 49)
#
# Run: 45, exploration: 0.03131473892591842, score: 10
# Scores: (min: 8, avg: 16.755555555555556, max: 49)
#
# Run: 46, exploration: 0.02948667236521416, score: 13
# Scores: (min: 8, avg: 16.67391304347826, max: 49)
#
# Run: 47, exploration: 0.027626496583102015, score: 14
# Scores: (min: 8, avg: 16.617021276595743, max: 49)
#
# Run: 48, exploration: 0.025883670561501974, score: 14
# Scores: (min: 8, avg: 16.5625, max: 49)
#
# Run: 49, exploration: 0.024129537298457977, score: 15
# Scores: (min: 8, avg: 16.53061224489796, max: 49)
#
# Run: 50, exploration: 0.023065173234186005, score: 10
# Scores: (min: 8, avg: 16.4, max: 49)
#
# Run: 51, exploration: 0.022158551474944856, score: 9
# Scores: (min: 8, avg: 16.254901960784313, max: 49)
#
# Run: 52, exploration: 0.021394538952450012, score: 8
# Scores: (min: 8, avg: 16.096153846153847, max: 49)
#
# Run: 53, exploration: 0.020450816818411825, score: 10
# Scores: (min: 8, avg: 15.981132075471699, max: 49)
#
# Run: 54, exploration: 0.01954872266561937, score: 10
# Scores: (min: 8, avg: 15.87037037037037, max: 49)
#
# Run: 55, exploration: 0.018686420266267767, score: 10
# Scores: (min: 8, avg: 15.763636363636364, max: 49)
#
# Run: 56, exploration: 0.017951913959130504, score: 9
# Scores: (min: 8, avg: 15.642857142857142, max: 49)
#
# Run: 57, exploration: 0.01707424722777892, score: 11
# Scores: (min: 8, avg: 15.56140350877193, max: 49)
#
# Run: 58, exploration: 0.01632109498333433, score: 10
# Scores: (min: 8, avg: 15.46551724137931, max: 49)
#
# Run: 59, exploration: 0.015601164601953134, score: 10
# Scores: (min: 8, avg: 15.372881355932204, max: 49)
#
# Run: 60, exploration: 0.014987930304771725, score: 9
# Scores: (min: 8, avg: 15.266666666666667, max: 49)
#
# Run: 61, exploration: 0.014398800381387675, score: 9
# Scores: (min: 8, avg: 15.163934426229508, max: 49)
#
# Run: 62, exploration: 0.013694844909292236, score: 11
# Scores: (min: 8, avg: 15.096774193548388, max: 49)
#
# Run: 63, exploration: 0.012766746905164949, score: 15
# Scores: (min: 8, avg: 15.095238095238095, max: 49)
#
# Run: 64, exploration: 0.01202146005600684, score: 13
# Scores: (min: 8, avg: 15.0625, max: 49)
#
# Run: 65, exploration: 0.011319680961146208, score: 13
# Scores: (min: 8, avg: 15.03076923076923, max: 49)
#
# Run: 66, exploration: 0.010447285872500434, score: 17
# Scores: (min: 8, avg: 15.06060606060606, max: 49)
#
# Run: 67, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 15.119402985074627, max: 49)
#
# Run: 68, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.088235294117647, max: 49)
#
# Run: 69, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 15.173913043478262, max: 49)
#
# Run: 70, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 16.242857142857144, max: 90)
#
# Run: 71, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.183098591549296, max: 90)
#
# Run: 72, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.180555555555557, max: 90)
#
# Run: 73, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 17, max: 90)
#
# Run: 74, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 17.39189189189189, max: 90)
#
# Run: 75, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.346666666666668, max: 90)
#
# Run: 76, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.473684210526315, max: 90)
#
# Run: 77, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.623376623376622, max: 90)
#
# Run: 78, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.653846153846153, max: 90)
#
# Run: 79, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 17.89873417721519, max: 90)
#
# Run: 80, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.05, max: 90)
#
# Run: 81, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.19753086419753, max: 90)
#
# Run: 82, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18.24390243902439, max: 90)
#
# Run: 83, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 18.49397590361446, max: 90)
#
# Run: 84, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 18.773809523809526, max: 90)
# Run: 85, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 19.305882352941175, max: 90)
#
# Run: 86, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.290697674418606, max: 90)
#
# Run: 87, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.32183908045977, max: 90)
#
# Run: 88, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 19.363636363636363, max: 90)
#
# Run: 89, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 19.797752808988765, max: 90)
#
# Run: 90, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.866666666666667, max: 90)
#
# Run: 91, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.164835164835164, max: 90)
#
# Run: 92, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 20.315217391304348, max: 90)
#
# Run: 93, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 20.397849462365592, max: 90)
#
# Run: 94, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.43617021276596, max: 90)
#
# Run: 95, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 20.673684210526314, max: 90)
#
# Run: 96, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 21.583333333333332, max: 108)
#
# Run: 97, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 21.701030927835053, max: 108)
#
# Run: 98, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 22.091836734693878, max: 108)
#
# Run: 99, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 22.11111111111111, max: 108)
#
# Run: 100, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 22.29, max: 108)
#
# Run: 101, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 22.62, max: 108)
#
# Run: 102, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.68, max: 108)
#
# Run: 103, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 22.69, max: 108)
#
# Run: 104, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.74, max: 108)
#
# Run: 105, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 23.56, max: 108)
#
# Run: 106, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.6, max: 108)
#
# Run: 107, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 23.95, max: 108)
#
# Run: 108, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 24.62, max: 108)
#
# Run: 109, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 24.99, max: 108)
#
# Run: 110, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 26.15, max: 132)
#
# Run: 111, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 26.3, max: 132)
#
# Run: 112, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 27.1, max: 132)
#
# Run: 113, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 27.29, max: 132)
#
# Run: 114, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 28.2, max: 132)
#
# Run: 115, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 28.96, max: 132)
#
# Run: 116, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 29.51, max: 132)
#
# Run: 117, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 29.76, max: 132)
#
# Run: 118, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 30.53, max: 132)
#
# Run: 119, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 31.15, max: 132)
#
# Run: 120, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 31.44, max: 132)
#
# Run: 121, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 31.67, max: 132)
#
# Run: 122, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 32.39, max: 132)
#
# Run: 123, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 32.54, max: 132)
#
# Run: 124, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 32.86, max: 132)
#
# Run: 125, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 33.01, max: 132)
#
# Run: 126, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 33.31, max: 132)
#
# Run: 127, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 33.7, max: 132)
#
# Run: 128, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 33.97, max: 132)
#
# Run: 129, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 34.35, max: 132)
#
# Run: 130, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 34.69, max: 132)
#
# Run: 131, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 35.12, max: 132)
#
# Run: 132, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 35.17, max: 132)
#
# Run: 133, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 35.52, max: 132)
#
# Run: 134, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 35.9, max: 132)
#
# Run: 135, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 36.52, max: 132)
#
# Run: 136, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 37.46, max: 132)
#
# Run: 137, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 38.19, max: 132)
#
# Run: 138, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 38.57, max: 132)
#
# Run: 139, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 39.21, max: 132)
#
# Run: 140, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 39.8, max: 132)
#
# Run: 141, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 40.34, max: 132)
#
# Run: 142, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 40.8, max: 132)
#
# Run: 143, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 42.12, max: 143)
#
# Run: 144, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 42.66, max: 143)
#
# Run: 145, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 43.21, max: 143)
#
# Run: 146, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 44.38, max: 143)
#
# Run: 147, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 45, max: 143)
#
# Run: 148, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 46.15, max: 143)
#
# Run: 149, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 47.07, max: 143)
#
# Run: 150, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 47.98, max: 143)
#
# Run: 151, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 49.08, max: 143)
#
# Run: 152, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 50.12, max: 143)
#
# Run: 153, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 52.48, max: 246)
#
# Run: 154, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 54.39, max: 246)
#
# Run: 155, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 55.56, max: 246)
#
# Run: 156, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 56.6, max: 246)
#
# Run: 157, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 58.83, max: 246)
#
# Run: 158, exploration: 0.01, score: 330
# Scores: (min: 9, avg: 62.03, max: 330)
#
# Run: 159, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 64.07, max: 330)
#
# Run: 160, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 65.44, max: 330)
#
# Run: 161, exploration: 0.01, score: 424
# Scores: (min: 11, avg: 69.59, max: 424)
#
# Run: 162, exploration: 0.01, score: 198
# Scores: (min: 12, avg: 71.46, max: 424)
#
# Run: 163, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 72.62, max: 424)
#
# Run: 164, exploration: 0.01, score: 152
# Scores: (min: 12, avg: 74.01, max: 424)
#
# Run: 165, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 75.43, max: 424)
#
# Run: 166, exploration: 0.01, score: 159
# Scores: (min: 12, avg: 76.85, max: 424)
#
# Run: 167, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 78.31, max: 424)
#
# Run: 168, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 79.91, max: 424)
#
# Run: 169, exploration: 0.01, score: 191
# Scores: (min: 12, avg: 81.61, max: 424)
#
# Run: 170, exploration: 0.01, score: 186
# Scores: (min: 12, avg: 82.57, max: 424)
#
# Run: 171, exploration: 0.01, score: 211
# Scores: (min: 14, avg: 84.56, max: 424)
#
# Run: 172, exploration: 0.01, score: 286
# Scores: (min: 14, avg: 87.26, max: 424)
#
# Run: 173, exploration: 0.01, score: 434
# Scores: (min: 14, avg: 90.84, max: 434)
#
# Run: 174, exploration: 0.01, score: 413
# Scores: (min: 14, avg: 94.51, max: 434)
#
# Run: 175, exploration: 0.01, score: 218
# Scores: (min: 18, avg: 96.55, max: 434)
#
# Run: 176, exploration: 0.01, score: 195
# Scores: (min: 18, avg: 98.23, max: 434)
#
# Run: 177, exploration: 0.01, score: 229
# Scores: (min: 18, avg: 100.23, max: 434)
#
# Run: 178, exploration: 0.01, score: 208
# Scores: (min: 18, avg: 102.11, max: 434)
#
# Run: 179, exploration: 0.01, score: 216
# Scores: (min: 18, avg: 103.9, max: 434)
#
# Run: 180, exploration: 0.01, score: 193
# Scores: (min: 18, avg: 105.53, max: 434)
#
# Run: 181, exploration: 0.01, score: 201
# Scores: (min: 18, avg: 107.24, max: 434)
#
# Run: 182, exploration: 0.01, score: 303
# Scores: (min: 18, avg: 110.05, max: 434)
#
# Run: 183, exploration: 0.01, score: 219
# Scores: (min: 18, avg: 111.85, max: 434)
#
# Run: 184, exploration: 0.01, score: 273
# Scores: (min: 18, avg: 114.16, max: 434)
#
# Run: 185, exploration: 0.01, score: 207
# Scores: (min: 18, avg: 115.59, max: 434)
# Run: 186, exploration: 0.01, score: 173
# Scores: (min: 21, avg: 117.14, max: 434)
#
# Run: 187, exploration: 0.01, score: 175
# Scores: (min: 21, avg: 118.67, max: 434)
#
# Run: 188, exploration: 0.01, score: 194
# Scores: (min: 21, avg: 120.38, max: 434)
#
# Run: 189, exploration: 0.01, score: 204
# Scores: (min: 21, avg: 121.84, max: 434)
#
# Run: 190, exploration: 0.01, score: 170
# Scores: (min: 21, avg: 123.28, max: 434)
#
# Run: 191, exploration: 0.01, score: 191
# Scores: (min: 21, avg: 124.72, max: 434)
#
# Run: 192, exploration: 0.01, score: 192
# Scores: (min: 21, avg: 126.3, max: 434)
#
# Run: 193, exploration: 0.01, score: 183
# Scores: (min: 21, avg: 127.85, max: 434)
#
# Run: 194, exploration: 0.01, score: 159
# Scores: (min: 21, avg: 129.2, max: 434)
#
# Run: 195, exploration: 0.01, score: 201
# Scores: (min: 21, avg: 130.78, max: 434)
#
# Run: 196, exploration: 0.01, score: 184
# Scores: (min: 21, avg: 131.54, max: 434)
#
# Run: 197, exploration: 0.01, score: 205
# Scores: (min: 21, avg: 133.26, max: 434)
#
# Run: 198, exploration: 0.01, score: 173
# Scores: (min: 21, avg: 134.39, max: 434)
#
# Run: 199, exploration: 0.01, score: 180
# Scores: (min: 21, avg: 135.95, max: 434)
#
# Run: 200, exploration: 0.01, score: 162
# Scores: (min: 21, avg: 137.17, max: 434)
#
# Run: 201, exploration: 0.01, score: 168
# Scores: (min: 21, avg: 138.36, max: 434)
#
# Run: 202, exploration: 0.01, score: 176
# Scores: (min: 22, avg: 139.91, max: 434)
#
# Run: 203, exploration: 0.01, score: 183
# Scores: (min: 22, avg: 141.47, max: 434)
#
# Run: 204, exploration: 0.01, score: 171
# Scores: (min: 22, avg: 142.88, max: 434)
#
# Run: 205, exploration: 0.01, score: 216
# Scores: (min: 22, avg: 144.09, max: 434)
#
# Run: 206, exploration: 0.01, score: 200
# Scores: (min: 30, avg: 145.87, max: 434)
#
# Run: 207, exploration: 0.01, score: 181
# Scores: (min: 30, avg: 147.12, max: 434)
#
# Run: 208, exploration: 0.01, score: 164
# Scores: (min: 30, avg: 147.9, max: 434)
#
# Run: 209, exploration: 0.01, score: 155
# Scores: (min: 30, avg: 148.95, max: 434)
#
# Run: 210, exploration: 0.01, score: 160
# Scores: (min: 30, avg: 149.23, max: 434)
#
# Run: 211, exploration: 0.01, score: 192
# Scores: (min: 30, avg: 150.83, max: 434)
#
# Run: 212, exploration: 0.01, score: 165
# Scores: (min: 30, avg: 151.58, max: 434)
#
# Run: 213, exploration: 0.01, score: 173
# Scores: (min: 34, avg: 153.01, max: 434)
#
# Run: 214, exploration: 0.01, score: 152
# Scores: (min: 34, avg: 153.52, max: 434)
#
# Run: 215, exploration: 0.01, score: 175
# Scores: (min: 34, avg: 154.41, max: 434)
#
# Run: 216, exploration: 0.01, score: 172
# Scores: (min: 34, avg: 155.45, max: 434)
#
# Run: 217, exploration: 0.01, score: 172
# Scores: (min: 34, avg: 156.83, max: 434)
#
# Run: 218, exploration: 0.01, score: 151
# Scores: (min: 34, avg: 157.47, max: 434)
#
# Run: 219, exploration: 0.01, score: 162
# Scores: (min: 34, avg: 158.36, max: 434)
#
# Run: 220, exploration: 0.01, score: 158
# Scores: (min: 34, avg: 159.5, max: 434)
#
# Run: 221, exploration: 0.01, score: 171
# Scores: (min: 39, avg: 160.87, max: 434)
#
# Run: 222, exploration: 0.01, score: 158
# Scores: (min: 39, avg: 161.61, max: 434)
#
# Run: 223, exploration: 0.01, score: 162
# Scores: (min: 39, avg: 162.84, max: 434)
#
# Run: 224, exploration: 0.01, score: 164
# Scores: (min: 39, avg: 163.99, max: 434)
#
# Run: 225, exploration: 0.01, score: 172
# Scores: (min: 39, avg: 165.32, max: 434)
#
# Run: 226, exploration: 0.01, score: 155
# Scores: (min: 39, avg: 166.39, max: 434)
#
# Run: 227, exploration: 0.01, score: 143
# Scores: (min: 39, avg: 167.26, max: 434)
#
# Run: 228, exploration: 0.01, score: 163
# Scores: (min: 50, avg: 168.5, max: 434)
#
# Run: 229, exploration: 0.01, score: 165
# Scores: (min: 50, avg: 169.43, max: 434)
#
# Run: 230, exploration: 0.01, score: 152
# Scores: (min: 50, avg: 170.26, max: 434)
#
# Run: 231, exploration: 0.01, score: 166
# Scores: (min: 50, avg: 171.22, max: 434)
#
# Run: 232, exploration: 0.01, score: 161
# Scores: (min: 50, avg: 172.29, max: 434)
#
# Run: 233, exploration: 0.01, score: 187
# Scores: (min: 50, avg: 173.44, max: 434)
#
# Run: 234, exploration: 0.01, score: 179
# Scores: (min: 50, avg: 174.65, max: 434)
#
# Run: 235, exploration: 0.01, score: 162
# Scores: (min: 50, avg: 175.55, max: 434)
#
# Run: 236, exploration: 0.01, score: 156
# Scores: (min: 50, avg: 176.03, max: 434)
#
# Run: 237, exploration: 0.01, score: 168
# Scores: (min: 50, avg: 176.88, max: 434)
#
# Run: 238, exploration: 0.01, score: 169
# Scores: (min: 61, avg: 178.07, max: 434)
#
# Run: 239, exploration: 0.01, score: 183
# Scores: (min: 61, avg: 179.16, max: 434)
#
# Run: 240, exploration: 0.01, score: 153
# Scores: (min: 61, avg: 180, max: 434)
#
# Run: 241, exploration: 0.01, score: 145
# Scores: (min: 61, avg: 180.82, max: 434)
#
# Run: 242, exploration: 0.01, score: 162
# Scores: (min: 62, avg: 181.83, max: 434)
#
# Run: 243, exploration: 0.01, score: 157
# Scores: (min: 62, avg: 181.97, max: 434)
#
# Run: 244, exploration: 0.01, score: 177
# Scores: (min: 65, avg: 183.12, max: 434)
#
# Run: 245, exploration: 0.01, score: 156
# Scores: (min: 76, avg: 184.03, max: 434)
#
# Run: 246, exploration: 0.01, score: 162
# Scores: (min: 76, avg: 184.35, max: 434)
#
# Run: 247, exploration: 0.01, score: 151
# Scores: (min: 101, avg: 185.1, max: 434)
#
# Run: 248, exploration: 0.01, score: 159
# Scores: (min: 101, avg: 185.4, max: 434)
#
# Run: 249, exploration: 0.01, score: 176
# Scores: (min: 101, avg: 186.09, max: 434)
#
# Run: 250, exploration: 0.01, score: 145
# Scores: (min: 112, avg: 186.53, max: 434)
#
# Run: 251, exploration: 0.01, score: 167
# Scores: (min: 112, avg: 187.01, max: 434)
#
# Run: 252, exploration: 0.01, score: 171
# Scores: (min: 113, avg: 187.6, max: 434)
#
# Run: 253, exploration: 0.01, score: 159
# Scores: (min: 113, avg: 186.73, max: 434)
#
# Run: 254, exploration: 0.01, score: 159
# Scores: (min: 113, avg: 186.31, max: 434)
#
# Run: 255, exploration: 0.01, score: 164
# Scores: (min: 113, avg: 186.68, max: 434)
#
# Run: 256, exploration: 0.01, score: 148
# Scores: (min: 131, avg: 187.03, max: 434)
#
# Run: 257, exploration: 0.01, score: 155
# Scores: (min: 131, avg: 186.24, max: 434)
#
# Run: 258, exploration: 0.01, score: 151
# Scores: (min: 131, avg: 184.45, max: 434)
#
# Run: 259, exploration: 0.01, score: 173
# Scores: (min: 131, avg: 184.04, max: 434)
#
# Run: 260, exploration: 0.01, score: 156
# Scores: (min: 131, avg: 184.14, max: 434)
#
# Run: 261, exploration: 0.01, score: 155
# Scores: (min: 131, avg: 181.45, max: 434)
#
# Run: 262, exploration: 0.01, score: 161
# Scores: (min: 131, avg: 181.08, max: 434)
#
# Run: 263, exploration: 0.01, score: 171
# Scores: (min: 143, avg: 181.48, max: 434)
#
# Run: 264, exploration: 0.01, score: 169
# Scores: (min: 143, avg: 181.65, max: 434)
#
# Run: 265, exploration: 0.01, score: 167
# Scores: (min: 143, avg: 181.77, max: 434)
#
# Run: 266, exploration: 0.01, score: 159
# Scores: (min: 143, avg: 181.77, max: 434)
#
# Run: 267, exploration: 0.01, score: 164
# Scores: (min: 143, avg: 181.76, max: 434)
#
# Run: 268, exploration: 0.01, score: 180
# Scores: (min: 143, avg: 181.83, max: 434)
#
# Run: 269, exploration: 0.01, score: 173
# Scores: (min: 143, avg: 181.65, max: 434)
#
# Run: 270, exploration: 0.01, score: 159
# Scores: (min: 143, avg: 181.38, max: 434)
#
# Run: 271, exploration: 0.01, score: 156
# Scores: (min: 143, avg: 180.83, max: 434)
#
# Run: 272, exploration: 0.01, score: 173
# Scores: (min: 143, avg: 179.7, max: 434)
#
# Run: 273, exploration: 0.01, score: 174
# Scores: (min: 143, avg: 177.1, max: 413)
#
# Run: 274, exploration: 0.01, score: 160
# Scores: (min: 143, avg: 174.57, max: 303)
#
# Run: 275, exploration: 0.01, score: 157
# Scores: (min: 143, avg: 173.96, max: 303)
#
# Run: 276, exploration: 0.01, score: 168
# Scores: (min: 143, avg: 173.69, max: 303)
#
# Run: 277, exploration: 0.01, score: 170
# Scores: (min: 143, avg: 173.1, max: 303)
#
# Run: 278, exploration: 0.01, score: 169
# Scores: (min: 143, avg: 172.71, max: 303)
#
# Run: 279, exploration: 0.01, score: 162
# Scores: (min: 143, avg: 172.17, max: 303)
#
# Run: 280, exploration: 0.01, score: 153
# Scores: (min: 143, avg: 171.77, max: 303)
#
# Run: 281, exploration: 0.01, score: 161
# Scores: (min: 143, avg: 171.37, max: 303)
#
# Run: 282, exploration: 0.01, score: 173
# Scores: (min: 143, avg: 170.07, max: 273)
#
# Run: 283, exploration: 0.01, score: 158
# Scores: (min: 143, avg: 169.46, max: 273)
#
# Run: 284, exploration: 0.01, score: 174
# Scores: (min: 143, avg: 168.47, max: 216)
#
# Run: 285, exploration: 0.01, score: 162
# Scores: (min: 143, avg: 168.02, max: 216)
# Run: 286, exploration: 0.01, score: 182
# Scores: (min: 143, avg: 168.11, max: 216)
#
# Run: 287, exploration: 0.01, score: 177
# Scores: (min: 143, avg: 168.13, max: 216)
#
# Run: 288, exploration: 0.01, score: 157
# Scores: (min: 143, avg: 167.76, max: 216)
#
# Run: 289, exploration: 0.01, score: 161
# Scores: (min: 143, avg: 167.33, max: 216)
#
# Run: 290, exploration: 0.01, score: 159
# Scores: (min: 143, avg: 167.22, max: 216)
#
# Run: 291, exploration: 0.01, score: 165
# Scores: (min: 143, avg: 166.96, max: 216)
#
# Run: 292, exploration: 0.01, score: 165
# Scores: (min: 143, avg: 166.69, max: 216)
#
# Run: 293, exploration: 0.01, score: 149
# Scores: (min: 143, avg: 166.35, max: 216)
#
# Run: 294, exploration: 0.01, score: 155
# Scores: (min: 143, avg: 166.31, max: 216)
#
# Run: 295, exploration: 0.01, score: 172
# Scores: (min: 143, avg: 166.02, max: 216)
#
# Run: 296, exploration: 0.01, score: 169
# Scores: (min: 143, avg: 165.87, max: 216)
#
# Run: 297, exploration: 0.01, score: 170
# Scores: (min: 143, avg: 165.52, max: 216)
#
# Run: 298, exploration: 0.01, score: 165
# Scores: (min: 143, avg: 165.44, max: 216)
#
# Run: 299, exploration: 0.01, score: 160
# Scores: (min: 143, avg: 165.24, max: 216)
#
# Run: 300, exploration: 0.01, score: 157
# Scores: (min: 143, avg: 165.19, max: 216)
#
# Run: 301, exploration: 0.01, score: 154
# Scores: (min: 143, avg: 165.05, max: 216)
#
# Run: 302, exploration: 0.01, score: 168
# Scores: (min: 143, avg: 164.97, max: 216)
#
# Run: 303, exploration: 0.01, score: 172
# Scores: (min: 143, avg: 164.86, max: 216)
#
# Run: 304, exploration: 0.01, score: 159
# Scores: (min: 143, avg: 164.74, max: 216)
#
# Run: 305, exploration: 0.01, score: 173
# Scores: (min: 143, avg: 164.31, max: 200)
#
# Run: 306, exploration: 0.01, score: 168
# Scores: (min: 143, avg: 163.99, max: 192)
#
# Run: 307, exploration: 0.01, score: 203
# Scores: (min: 143, avg: 164.21, max: 203)
#
# Run: 308, exploration: 0.01, score: 194
# Scores: (min: 143, avg: 164.51, max: 203)
#
# Run: 309, exploration: 0.01, score: 187
# Scores: (min: 143, avg: 164.83, max: 203)
#
# Run: 310, exploration: 0.01, score: 173
# Scores: (min: 143, avg: 164.96, max: 203)
#
# Run: 311, exploration: 0.01, score: 191
# Scores: (min: 143, avg: 164.95, max: 203)
#
# Run: 312, exploration: 0.01, score: 190
# Scores: (min: 143, avg: 165.2, max: 203)
#
# Run: 313, exploration: 0.01, score: 185
# Scores: (min: 143, avg: 165.32, max: 203)
#
# Run: 314, exploration: 0.01, score: 172
# Scores: (min: 143, avg: 165.52, max: 203)
#
# Run: 315, exploration: 0.01, score: 207
# Scores: (min: 143, avg: 165.84, max: 207)
#
# Run: 316, exploration: 0.01, score: 167
# Scores: (min: 143, avg: 165.79, max: 207)
#
# Run: 317, exploration: 0.01, score: 175
# Scores: (min: 143, avg: 165.82, max: 207)
#
# Run: 318, exploration: 0.01, score: 177
# Scores: (min: 143, avg: 166.08, max: 207)
#
# Run: 319, exploration: 0.01, score: 188
# Scores: (min: 143, avg: 166.34, max: 207)
#
# Run: 320, exploration: 0.01, score: 211
# Scores: (min: 143, avg: 166.87, max: 211)
#
# Run: 321, exploration: 0.01, score: 199
# Scores: (min: 143, avg: 167.15, max: 211)
#
# Run: 322, exploration: 0.01, score: 181
# Scores: (min: 143, avg: 167.38, max: 211)
#
# Run: 323, exploration: 0.01, score: 206
# Scores: (min: 143, avg: 167.82, max: 211)
#
# Run: 324, exploration: 0.01, score: 220
# Scores: (min: 143, avg: 168.38, max: 220)
#
# Run: 325, exploration: 0.01, score: 179
# Scores: (min: 143, avg: 168.45, max: 220)
#
# Run: 326, exploration: 0.01, score: 171
# Scores: (min: 143, avg: 168.61, max: 220)
#
# Run: 327, exploration: 0.01, score: 158
# Scores: (min: 145, avg: 168.76, max: 220)
#
# Run: 328, exploration: 0.01, score: 192
# Scores: (min: 145, avg: 169.05, max: 220)
#
# Run: 329, exploration: 0.01, score: 160
# Scores: (min: 145, avg: 169, max: 220)
#
# Run: 330, exploration: 0.01, score: 198
# Scores: (min: 145, avg: 169.46, max: 220)
#
# Run: 331, exploration: 0.01, score: 178
# Scores: (min: 145, avg: 169.58, max: 220)
#
# Run: 332, exploration: 0.01, score: 224
# Scores: (min: 145, avg: 170.21, max: 224)
#
# Run: 333, exploration: 0.01, score: 179
# Scores: (min: 145, avg: 170.13, max: 224)
#
# Run: 334, exploration: 0.01, score: 160
# Scores: (min: 145, avg: 169.94, max: 224)
#
# Run: 335, exploration: 0.01, score: 180
# Scores: (min: 145, avg: 170.12, max: 224)
#
# Run: 336, exploration: 0.01, score: 200
# Scores: (min: 145, avg: 170.56, max: 224)
#
# Run: 337, exploration: 0.01, score: 185
# Scores: (min: 145, avg: 170.73, max: 224)
#
# Run: 338, exploration: 0.01, score: 199
# Scores: (min: 145, avg: 171.03, max: 224)
#
# Run: 339, exploration: 0.01, score: 169
# Scores: (min: 145, avg: 170.89, max: 224)
#
# Run: 340, exploration: 0.01, score: 221
# Scores: (min: 145, avg: 171.57, max: 224)
#
# Run: 341, exploration: 0.01, score: 185
# Scores: (min: 145, avg: 171.97, max: 224)
#
# Run: 342, exploration: 0.01, score: 218
# Scores: (min: 145, avg: 172.53, max: 224)
#
# Run: 343, exploration: 0.01, score: 209
# Scores: (min: 145, avg: 173.05, max: 224)
#
# Run: 344, exploration: 0.01, score: 180
# Scores: (min: 145, avg: 173.08, max: 224)
#
# Run: 345, exploration: 0.01, score: 217
# Scores: (min: 145, avg: 173.69, max: 224)
#
# Run: 346, exploration: 0.01, score: 170
# Scores: (min: 145, avg: 173.77, max: 224)
#
# Run: 347, exploration: 0.01, score: 197
# Scores: (min: 145, avg: 174.23, max: 224)
#
# Run: 348, exploration: 0.01, score: 200
# Scores: (min: 145, avg: 174.64, max: 224)
#
# Run: 349, exploration: 0.01, score: 225
# Scores: (min: 145, avg: 175.13, max: 225)
#
# Run: 350, exploration: 0.01, score: 253
# Scores: (min: 148, avg: 176.21, max: 253)
#
# Run: 351, exploration: 0.01, score: 289
# Scores: (min: 148, avg: 177.43, max: 289)
#
# Run: 352, exploration: 0.01, score: 241
# Scores: (min: 148, avg: 178.13, max: 289)
#
# Run: 353, exploration: 0.01, score: 203
# Scores: (min: 148, avg: 178.57, max: 289)
#
# Run: 354, exploration: 0.01, score: 243
# Scores: (min: 148, avg: 179.41, max: 289)
#
# Run: 355, exploration: 0.01, score: 204
# Scores: (min: 148, avg: 179.81, max: 289)
#
# Run: 356, exploration: 0.01, score: 190
# Scores: (min: 149, avg: 180.23, max: 289)
#
# Run: 357, exploration: 0.01, score: 177
# Scores: (min: 149, avg: 180.45, max: 289)
#
# Run: 358, exploration: 0.01, score: 174
# Scores: (min: 149, avg: 180.68, max: 289)
#
# Run: 359, exploration: 0.01, score: 177
# Scores: (min: 149, avg: 180.72, max: 289)
#
# Run: 360, exploration: 0.01, score: 165
# Scores: (min: 149, avg: 180.81, max: 289)
#
# Run: 361, exploration: 0.01, score: 156
# Scores: (min: 149, avg: 180.82, max: 289)
#
# Run: 362, exploration: 0.01, score: 169
# Scores: (min: 149, avg: 180.9, max: 289)
#
# Run: 363, exploration: 0.01, score: 156
# Scores: (min: 149, avg: 180.75, max: 289)
#
# Run: 364, exploration: 0.01, score: 184
# Scores: (min: 149, avg: 180.9, max: 289)
#
# Run: 365, exploration: 0.01, score: 172
# Scores: (min: 149, avg: 180.95, max: 289)
#
# Run: 366, exploration: 0.01, score: 165
# Scores: (min: 149, avg: 181.01, max: 289)
#
# Run: 367, exploration: 0.01, score: 179
# Scores: (min: 149, avg: 181.16, max: 289)
#
# Run: 368, exploration: 0.01, score: 170
# Scores: (min: 149, avg: 181.06, max: 289)
#
# Run: 369, exploration: 0.01, score: 168
# Scores: (min: 149, avg: 181.01, max: 289)
#
# Run: 370, exploration: 0.01, score: 212
# Scores: (min: 149, avg: 181.54, max: 289)
#
# Run: 371, exploration: 0.01, score: 203
# Scores: (min: 149, avg: 182.01, max: 289)
#
# Run: 372, exploration: 0.01, score: 162
# Scores: (min: 149, avg: 181.9, max: 289)
#
# Run: 373, exploration: 0.01, score: 200
# Scores: (min: 149, avg: 182.16, max: 289)
#
# Run: 374, exploration: 0.01, score: 187
# Scores: (min: 149, avg: 182.43, max: 289)
#
# Run: 375, exploration: 0.01, score: 197
# Scores: (min: 149, avg: 182.83, max: 289)
#
# Run: 376, exploration: 0.01, score: 159
# Scores: (min: 149, avg: 182.74, max: 289)
#
# Run: 377, exploration: 0.01, score: 220
# Scores: (min: 149, avg: 183.24, max: 289)
#
# Run: 378, exploration: 0.01, score: 188
# Scores: (min: 149, avg: 183.43, max: 289)
#
# Run: 379, exploration: 0.01, score: 205
# Scores: (min: 149, avg: 183.86, max: 289)
#
# Run: 380, exploration: 0.01, score: 140
# Scores: (min: 140, avg: 183.73, max: 289)
#
# Run: 381, exploration: 0.01, score: 156
# Scores: (min: 140, avg: 183.68, max: 289)
#
# Run: 382, exploration: 0.01, score: 215
# Scores: (min: 140, avg: 184.1, max: 289)
#
# Run: 383, exploration: 0.01, score: 185
# Scores: (min: 140, avg: 184.37, max: 289)
#
# Run: 384, exploration: 0.01, score: 459
# Scores: (min: 140, avg: 187.22, max: 459)
# Run: 385, exploration: 0.01, score: 184
# Scores: (min: 140, avg: 187.44, max: 459)
#
# Run: 386, exploration: 0.01, score: 198
# Scores: (min: 140, avg: 187.6, max: 459)
#
# Run: 387, exploration: 0.01, score: 200
# Scores: (min: 140, avg: 187.83, max: 459)
#
# Run: 388, exploration: 0.01, score: 190
# Scores: (min: 140, avg: 188.16, max: 459)
#
# Run: 389, exploration: 0.01, score: 213
# Scores: (min: 140, avg: 188.68, max: 459)
#
# Run: 390, exploration: 0.01, score: 165
# Scores: (min: 140, avg: 188.74, max: 459)
#
# Run: 391, exploration: 0.01, score: 168
# Scores: (min: 140, avg: 188.77, max: 459)
#
# Run: 392, exploration: 0.01, score: 169
# Scores: (min: 140, avg: 188.81, max: 459)
#
# Run: 393, exploration: 0.01, score: 177
# Scores: (min: 140, avg: 189.09, max: 459)
#
# Run: 394, exploration: 0.01, score: 208
# Scores: (min: 140, avg: 189.62, max: 459)
#
# Run: 395, exploration: 0.01, score: 167
# Scores: (min: 140, avg: 189.57, max: 459)
#
# Run: 396, exploration: 0.01, score: 174
# Scores: (min: 140, avg: 189.62, max: 459)
#
# Run: 397, exploration: 0.01, score: 177
# Scores: (min: 140, avg: 189.69, max: 459)
#
# Run: 398, exploration: 0.01, score: 231
# Scores: (min: 140, avg: 190.35, max: 459)
#
# Run: 399, exploration: 0.01, score: 261
# Scores: (min: 140, avg: 191.36, max: 459)
#
# Run: 400, exploration: 0.01, score: 207
# Scores: (min: 140, avg: 191.86, max: 459)
#
# Run: 401, exploration: 0.01, score: 207
# Scores: (min: 140, avg: 192.39, max: 459)
#
# Run: 402, exploration: 0.01, score: 214
# Scores: (min: 140, avg: 192.85, max: 459)
#
# Run: 403, exploration: 0.01, score: 184
# Scores: (min: 140, avg: 192.97, max: 459)
#
# Run: 404, exploration: 0.01, score: 169
# Scores: (min: 140, avg: 193.07, max: 459)
#
# Run: 405, exploration: 0.01, score: 162
# Scores: (min: 140, avg: 192.96, max: 459)
#
# Run: 406, exploration: 0.01, score: 169
# Scores: (min: 140, avg: 192.97, max: 459)
#
# Run: 407, exploration: 0.01, score: 204
# Scores: (min: 140, avg: 192.98, max: 459)
#
# Run: 408, exploration: 0.01, score: 211
# Scores: (min: 140, avg: 193.15, max: 459)
#
# Run: 409, exploration: 0.01, score: 179
# Scores: (min: 140, avg: 193.07, max: 459)
#
# Run: 410, exploration: 0.01, score: 189
# Scores: (min: 140, avg: 193.23, max: 459)
#
# Run: 411, exploration: 0.01, score: 215
# Scores: (min: 140, avg: 193.47, max: 459)
#
# Run: 412, exploration: 0.01, score: 200
# Scores: (min: 140, avg: 193.57, max: 459)
#
# Run: 413, exploration: 0.01, score: 184
# Scores: (min: 140, avg: 193.56, max: 459)
#
# Run: 414, exploration: 0.01, score: 190
# Scores: (min: 140, avg: 193.74, max: 459)
#
# Run: 415, exploration: 0.01, score: 184
# Scores: (min: 140, avg: 193.51, max: 459)
#
# Run: 416, exploration: 0.01, score: 177
# Scores: (min: 140, avg: 193.61, max: 459)
#
# Run: 417, exploration: 0.01, score: 187
# Scores: (min: 140, avg: 193.73, max: 459)
#
# Run: 418, exploration: 0.01, score: 188
# Scores: (min: 140, avg: 193.84, max: 459)
#
# Run: 419, exploration: 0.01, score: 204
# Scores: (min: 140, avg: 194, max: 459)
#
# Run: 420, exploration: 0.01, score: 192
# Scores: (min: 140, avg: 193.81, max: 459)
#
# Run: 421, exploration: 0.01, score: 147
# Scores: (min: 140, avg: 193.29, max: 459)
#
# Run: 422, exploration: 0.01, score: 177
# Scores: (min: 140, avg: 193.25, max: 459)
#
# Run: 423, exploration: 0.01, score: 166
# Scores: (min: 140, avg: 192.85, max: 459)
#
# Run: 424, exploration: 0.01, score: 174
# Scores: (min: 140, avg: 192.39, max: 459)
#
# Run: 425, exploration: 0.01, score: 192
# Scores: (min: 140, avg: 192.52, max: 459)
#
# Run: 426, exploration: 0.01, score: 216
# Scores: (min: 140, avg: 192.97, max: 459)
#
# Run: 427, exploration: 0.01, score: 179
# Scores: (min: 140, avg: 193.18, max: 459)
#
# Run: 428, exploration: 0.01, score: 162
# Scores: (min: 140, avg: 192.88, max: 459)
#
# Run: 429, exploration: 0.01, score: 188
# Scores: (min: 140, avg: 193.16, max: 459)
#
# Run: 430, exploration: 0.01, score: 170
# Scores: (min: 140, avg: 192.88, max: 459)
#
# Run: 431, exploration: 0.01, score: 185
# Scores: (min: 140, avg: 192.95, max: 459)
#
# Run: 432, exploration: 0.01, score: 164
# Scores: (min: 140, avg: 192.35, max: 459)
#
# Run: 433, exploration: 0.01, score: 188
# Scores: (min: 140, avg: 192.44, max: 459)
#
# Run: 434, exploration: 0.01, score: 199
# Scores: (min: 140, avg: 192.83, max: 459)
#
# Run: 435, exploration: 0.01, score: 180
# Scores: (min: 140, avg: 192.83, max: 459)
#
# Run: 436, exploration: 0.01, score: 192
# Scores: (min: 140, avg: 192.75, max: 459)
#
# Run: 437, exploration: 0.01, score: 196
# Scores: (min: 140, avg: 192.86, max: 459)
#
# Run: 438, exploration: 0.01, score: 195
# Scores: (min: 140, avg: 192.82, max: 459)
#
# Run: 439, exploration: 0.01, score: 198
# Scores: (min: 140, avg: 193.11, max: 459)
#
# Run: 440, exploration: 0.01, score: 224
# Scores: (min: 140, avg: 193.14, max: 459)
#
# Run: 441, exploration: 0.01, score: 197
# Scores: (min: 140, avg: 193.26, max: 459)
#
# Run: 442, exploration: 0.01, score: 254
# Scores: (min: 140, avg: 193.62, max: 459)
#
# Run: 443, exploration: 0.01, score: 217
# Scores: (min: 140, avg: 193.7, max: 459)
#
# Run: 444, exploration: 0.01, score: 173
# Scores: (min: 140, avg: 193.63, max: 459)
#
# Run: 445, exploration: 0.01, score: 168
# Scores: (min: 140, avg: 193.14, max: 459)
#
# Run: 446, exploration: 0.01, score: 181
# Scores: (min: 140, avg: 193.25, max: 459)
#
# Run: 447, exploration: 0.01, score: 214
# Scores: (min: 140, avg: 193.42, max: 459)
#
# Run: 448, exploration: 0.01, score: 175
# Scores: (min: 140, avg: 193.17, max: 459)
#
# Run: 449, exploration: 0.01, score: 263
# Scores: (min: 140, avg: 193.55, max: 459)
#
# Run: 450, exploration: 0.01, score: 198
# Scores: (min: 140, avg: 193, max: 459)
#
# Run: 451, exploration: 0.01, score: 171
# Scores: (min: 140, avg: 191.82, max: 459)
#
# Run: 452, exploration: 0.01, score: 174
# Scores: (min: 140, avg: 191.15, max: 459)
#
# Run: 453, exploration: 0.01, score: 174
# Scores: (min: 140, avg: 190.86, max: 459)
#
# Run: 454, exploration: 0.01, score: 190
# Scores: (min: 140, avg: 190.33, max: 459)
#
# Run: 455, exploration: 0.01, score: 174
# Scores: (min: 140, avg: 190.03, max: 459)
#
# Run: 456, exploration: 0.01, score: 176
# Scores: (min: 140, avg: 189.89, max: 459)
#
# Run: 457, exploration: 0.01, score: 195
# Scores: (min: 140, avg: 190.07, max: 459)
#
# Run: 458, exploration: 0.01, score: 194
# Scores: (min: 140, avg: 190.27, max: 459)
#
# Run: 459, exploration: 0.01, score: 324
# Scores: (min: 140, avg: 191.74, max: 459)
#
# Run: 460, exploration: 0.01, score: 235
# Scores: (min: 140, avg: 192.44, max: 459)
#
# Run: 461, exploration: 0.01, score: 190
# Scores: (min: 140, avg: 192.78, max: 459)
#
# Run: 462, exploration: 0.01, score: 241
# Scores: (min: 140, avg: 193.5, max: 459)
#
# Run: 463, exploration: 0.01, score: 225
# Scores: (min: 140, avg: 194.19, max: 459)
#
# Run: 464, exploration: 0.01, score: 177
# Scores: (min: 140, avg: 194.12, max: 459)
#
# Run: 465, exploration: 0.01, score: 202
# Scores: (min: 140, avg: 194.42, max: 459)
#
# Run: 466, exploration: 0.01, score: 267
# Scores: (min: 140, avg: 195.44, max: 459)
#
# Solved in 366 runs, 466 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-470c1dfc2ccb> in <module>
#      88             dqn_solver.experience_replay()
#      89
# ---> 90 cartpole()
#
# <ipython-input-9-470c1dfc2ccb> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # Discount Factor (Gamma) changed
#
#     GAMMA: 0.95 --> 0.99
#
# Solved in 84 runs, 184 total runs.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.99  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()  

cartpole()
# Out:
# Using TensorFlow backend.
# Run: 1, exploration: 0.946354579813443, score: 31
# Scores: (min: 31, avg: 31, max: 31)
#
# Run: 2, exploration: 0.9046104802746175, score: 10
# Scores: (min: 10, avg: 20.5, max: 31)
#
# Run: 3, exploration: 0.8183201210226743, score: 21
# Scores: (min: 10, avg: 20.666666666666668, max: 31)
#
# Run: 4, exploration: 0.778312557068642, score: 11
# Scores: (min: 10, avg: 18.25, max: 31)
#
# Run: 5, exploration: 0.7076077347272662, score: 20
# Scores: (min: 10, avg: 18.6, max: 31)
#
# Run: 6, exploration: 0.6662995813682115, score: 13
# Scores: (min: 10, avg: 17.666666666666668, max: 31)
#
# Run: 7, exploration: 0.5937455908197752, score: 24
# Scores: (min: 10, avg: 18.571428571428573, max: 31)
#
# Run: 8, exploration: 0.5618938591163328, score: 12
# Scores: (min: 10, avg: 17.75, max: 31)
#
# Run: 9, exploration: 0.531750826943791, score: 12
# Scores: (min: 10, avg: 17.11111111111111, max: 31)
#
# Run: 10, exploration: 0.49571413690105054, score: 15
# Scores: (min: 10, avg: 16.9, max: 31)
#
# Run: 11, exploration: 0.46444185833082485, score: 14
# Scores: (min: 10, avg: 16.636363636363637, max: 31)
#
# Run: 12, exploration: 0.446186062443672, score: 9
# Scores: (min: 9, avg: 16, max: 31)
#
# Run: 13, exploration: 0.4222502236424958, score: 12
# Scores: (min: 9, avg: 15.692307692307692, max: 31)
#
# Run: 14, exploration: 0.4016064652978155, score: 11
# Scores: (min: 9, avg: 15.357142857142858, max: 31)
#
# Run: 15, exploration: 0.37816180712868996, score: 13
# Scores: (min: 9, avg: 15.2, max: 31)
#
# Run: 16, exploration: 0.3578751580867638, score: 12
# Scores: (min: 9, avg: 15, max: 31)
#
# Run: 17, exploration: 0.3386767948568688, score: 12
# Scores: (min: 9, avg: 14.823529411764707, max: 31)
#
# Run: 18, exploration: 0.3237376186352221, score: 10
# Scores: (min: 9, avg: 14.555555555555555, max: 31)
#
# Run: 19, exploration: 0.30945741577570285, score: 10
# Scores: (min: 9, avg: 14.31578947368421, max: 31)
#
# Run: 20, exploration: 0.29729358661854943, score: 9
# Scores: (min: 9, avg: 14.05, max: 31)
#
# Run: 21, exploration: 0.28417984116121187, score: 10
# Scores: (min: 9, avg: 13.857142857142858, max: 31)
#
# Run: 22, exploration: 0.2702863258025825, score: 11
# Scores: (min: 9, avg: 13.727272727272727, max: 31)
#
# Run: 23, exploration: 0.2583638820072446, score: 10
# Scores: (min: 9, avg: 13.565217391304348, max: 31)
#
# Run: 24, exploration: 0.24328132378095624, score: 13
# Scores: (min: 9, avg: 13.541666666666666, max: 31)
#
# Run: 25, exploration: 0.23371867538818816, score: 9
# Scores: (min: 9, avg: 13.36, max: 31)
#
# Run: 26, exploration: 0.22453190559909803, score: 9
# Scores: (min: 9, avg: 13.192307692307692, max: 31)
#
# Run: 27, exploration: 0.21462770857094118, score: 10
# Scores: (min: 9, avg: 13.074074074074074, max: 31)
#
# Run: 28, exploration: 0.20516038984972615, score: 10
# Scores: (min: 9, avg: 12.964285714285714, max: 31)
#
# Run: 29, exploration: 0.19513012515638165, score: 11
# Scores: (min: 9, avg: 12.89655172413793, max: 31)
#
# Run: 30, exploration: 0.18840216465300522, score: 8
# Scores: (min: 8, avg: 12.733333333333333, max: 31)
#
# Run: 31, exploration: 0.18190617987607657, score: 8
# Scores: (min: 8, avg: 12.580645161290322, max: 31)
#
# Run: 32, exploration: 0.17388222158237718, score: 10
# Scores: (min: 8, avg: 12.5, max: 31)
#
# Run: 33, exploration: 0.16538114245489302, score: 11
# Scores: (min: 8, avg: 12.454545454545455, max: 31)
#
# Run: 34, exploration: 0.15650920157696743, score: 12
# Scores: (min: 8, avg: 12.441176470588236, max: 31)
#
# Run: 35, exploration: 0.14960551470448571, score: 10
# Scores: (min: 8, avg: 12.371428571428572, max: 31)
#
# Run: 36, exploration: 0.14300635237083656, score: 10
# Scores: (min: 8, avg: 12.305555555555555, max: 31)
#
# Run: 37, exploration: 0.13669828187021155, score: 10
# Scores: (min: 8, avg: 12.243243243243244, max: 31)
#
# Run: 38, exploration: 0.13066846301911936, score: 10
# Scores: (min: 8, avg: 12.18421052631579, max: 31)
#
# Run: 39, exploration: 0.11702497557911415, score: 23
# Scores: (min: 8, avg: 12.461538461538462, max: 31)
#
# Run: 40, exploration: 0.11299003011401039, score: 8
# Scores: (min: 8, avg: 12.35, max: 31)
#
# Run: 41, exploration: 0.10800599224428936, score: 10
# Scores: (min: 8, avg: 12.292682926829269, max: 31)
#
# Run: 42, exploration: 0.10272559337455119, score: 11
# Scores: (min: 8, avg: 12.261904761904763, max: 31)
#
# Run: 43, exploration: 0.09672876157528969, score: 13
# Scores: (min: 8, avg: 12.279069767441861, max: 31)
#
# Run: 44, exploration: 0.09246201511725258, score: 10
# Scores: (min: 8, avg: 12.227272727272727, max: 31)
#
# Run: 45, exploration: 0.08838347664452084, score: 10
# Scores: (min: 8, avg: 12.177777777777777, max: 31)
#
# Run: 46, exploration: 0.08533607153708872, score: 8
# Scores: (min: 8, avg: 12.08695652173913, max: 31)
#
# Run: 47, exploration: 0.08198177029173696, score: 9
# Scores: (min: 8, avg: 12.02127659574468, max: 31)
#
# Run: 48, exploration: 0.07836551983717477, score: 10
# Scores: (min: 8, avg: 11.979166666666666, max: 31)
#
# Run: 49, exploration: 0.07490878371492794, score: 10
# Scores: (min: 8, avg: 11.938775510204081, max: 31)
#
# Run: 50, exploration: 0.0712465030521374, score: 11
# Scores: (min: 8, avg: 11.92, max: 31)
#
# Run: 51, exploration: 0.0677632708131484, score: 11
# Scores: (min: 8, avg: 11.901960784313726, max: 31)
#
# Run: 52, exploration: 0.06542683706543727, score: 8
# Scores: (min: 8, avg: 11.826923076923077, max: 31)
#
# Run: 53, exploration: 0.06317096204211972, score: 8
# Scores: (min: 8, avg: 11.754716981132075, max: 31)
#
# Run: 54, exploration: 0.060687903789832374, score: 9
# Scores: (min: 8, avg: 11.703703703703704, max: 31)
#
# Run: 55, exploration: 0.05743227569078546, score: 12
# Scores: (min: 8, avg: 11.709090909090909, max: 31)
#
# Run: 56, exploration: 0.05517478773284426, score: 9
# Scores: (min: 8, avg: 11.660714285714286, max: 31)
#
# Run: 57, exploration: 0.053006034755694834, score: 9
# Scores: (min: 8, avg: 11.614035087719298, max: 31)
#
# Run: 58, exploration: 0.05066791621302729, score: 10
# Scores: (min: 8, avg: 11.586206896551724, max: 31)
#
# Run: 59, exploration: 0.048432933065126825, score: 10
# Scores: (min: 8, avg: 11.559322033898304, max: 31)
#
# Run: 60, exploration: 0.04652918187562211, score: 9
# Scores: (min: 8, avg: 11.516666666666667, max: 31)
#
# Run: 61, exploration: 0.04447676004441063, score: 10
# Scores: (min: 8, avg: 11.491803278688524, max: 31)
#
# Run: 62, exploration: 0.04272851397543923, score: 9
# Scores: (min: 8, avg: 11.451612903225806, max: 31)
#
# Run: 63, exploration: 0.04104898613852031, score: 9
# Scores: (min: 8, avg: 11.412698412698413, max: 31)
#
# Run: 64, exploration: 0.03923829805195549, score: 10
# Scores: (min: 8, avg: 11.390625, max: 31)
#
# Run: 65, exploration: 0.03750748018035199, score: 10
# Scores: (min: 8, avg: 11.36923076923077, max: 31)
#
# Run: 66, exploration: 0.03585300941485119, score: 10
# Scores: (min: 8, avg: 11.348484848484848, max: 31)
#
# Run: 67, exploration: 0.03461682084029365, score: 8
# Scores: (min: 8, avg: 11.298507462686567, max: 31)
#
# Run: 68, exploration: 0.032924408985721944, score: 11
# Scores: (min: 8, avg: 11.294117647058824, max: 31)
#
# Run: 69, exploration: 0.03147209942303359, score: 10
# Scores: (min: 8, avg: 11.27536231884058, max: 31)
#
# Run: 70, exploration: 0.030083851847510768, score: 10
# Scores: (min: 8, avg: 11.257142857142858, max: 31)
#
# Run: 71, exploration: 0.028901347193857643, score: 9
# Scores: (min: 8, avg: 11.225352112676056, max: 31)
#
# Run: 72, exploration: 0.027765323199097504, score: 9
# Scores: (min: 8, avg: 11.194444444444445, max: 31)
#
# Run: 73, exploration: 0.02654058308574668, score: 10
# Scores: (min: 8, avg: 11.178082191780822, max: 31)
#
# Run: 74, exploration: 0.02524301744132218, score: 11
# Scores: (min: 8, avg: 11.175675675675675, max: 31)
#
# Run: 75, exploration: 0.024129537298457977, score: 10
# Scores: (min: 8, avg: 11.16, max: 31)
#
# Run: 76, exploration: 0.023065173234186005, score: 10
# Scores: (min: 8, avg: 11.144736842105264, max: 31)
#
# Run: 77, exploration: 0.022047758717570132, score: 10
# Scores: (min: 8, avg: 11.12987012987013, max: 31)
#
# Run: 78, exploration: 0.021181128426399323, score: 9
# Scores: (min: 8, avg: 11.102564102564102, max: 31)
#
# Run: 79, exploration: 0.020450816818411825, score: 8
# Scores: (min: 8, avg: 11.063291139240507, max: 31)
#
# Run: 80, exploration: 0.019450979052291272, score: 11
# Scores: (min: 8, avg: 11.0625, max: 31)
#
# Run: 81, exploration: 0.018780321875645996, score: 8
# Scores: (min: 8, avg: 11.024691358024691, max: 31)
# Run: 82, exploration: 0.018042124582040707, score: 9
# Scores: (min: 8, avg: 11, max: 31)
#
# Run: 83, exploration: 0.017332943577287888, score: 9
# Scores: (min: 8, avg: 10.975903614457831, max: 31)
#
# Run: 84, exploration: 0.016485538227150154, score: 11
# Scores: (min: 8, avg: 10.976190476190476, max: 31)
#
# Run: 85, exploration: 0.01583754189442009, score: 9
# Scores: (min: 8, avg: 10.952941176470588, max: 31)
#
# Run: 86, exploration: 0.014987930304771725, score: 12
# Scores: (min: 8, avg: 10.965116279069768, max: 31)
#
# Run: 87, exploration: 0.013422995398979608, score: 23
# Scores: (min: 8, avg: 11.10344827586207, max: 31)
#
# Run: 88, exploration: 0.01283090141222608, score: 10
# Scores: (min: 8, avg: 11.090909090909092, max: 31)
#
# Run: 89, exploration: 0.012388500230681249, score: 8
# Scores: (min: 8, avg: 11.0561797752809, max: 31)
#
# Run: 90, exploration: 0.01184203826198843, score: 10
# Scores: (min: 8, avg: 11.044444444444444, max: 31)
#
# Run: 91, exploration: 0.01137656378004644, score: 9
# Scores: (min: 8, avg: 11.021978021978022, max: 31)
#
# Run: 92, exploration: 0.010447285872500434, score: 18
# Scores: (min: 8, avg: 11.097826086956522, max: 31)
#
# Run: 93, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.172043010752688, max: 31)
#
# Run: 94, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.329787234042554, max: 31)
#
# Run: 95, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 11.557894736842105, max: 33)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.53125, max: 33)
#
# Run: 97, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 11.721649484536082, max: 33)
#
# Run: 98, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 11.959183673469388, max: 35)
#
# Run: 99, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 12.090909090909092, max: 35)
#
# Run: 100, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.19, max: 35)
#
# Run: 101, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 12.87, max: 99)
#
# Run: 102, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 13.53, max: 99)
#
# Run: 103, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 14.21, max: 99)
#
# Run: 104, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 14.62, max: 99)
#
# Run: 105, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 14.97, max: 99)
#
# Run: 106, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 15.39, max: 99)
#
# Run: 107, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 15.63, max: 99)
#
# Run: 108, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 16.07, max: 99)
#
# Run: 109, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 16.61, max: 99)
#
# Run: 110, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 17.85, max: 139)
#
# Run: 111, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 18.78, max: 139)
#
# Run: 112, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 19.46, max: 139)
#
# Run: 113, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 19.85, max: 139)
#
# Run: 114, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 20.45, max: 139)
#
# Run: 115, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 21, max: 139)
#
# Run: 116, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 21.62, max: 139)
#
# Run: 117, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 22.18, max: 139)
#
# Run: 118, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 22.6, max: 139)
#
# Run: 119, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 23.38, max: 139)
#
# Run: 120, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 24.22, max: 139)
#
# Run: 121, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 25.77, max: 165)
#
# Run: 122, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 26.93, max: 165)
#
# Run: 123, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 28.32, max: 165)
#
# Run: 124, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 29.41, max: 165)
#
# Run: 125, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 30.78, max: 165)
#
# Run: 126, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 32.78, max: 209)
#
# Run: 127, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 34.52, max: 209)
#
# Run: 128, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 35.5, max: 209)
#
# Run: 129, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 36.86, max: 209)
#
# Run: 130, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 39.02, max: 224)
#
# Run: 131, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 41.12, max: 224)
#
# Run: 132, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 43.63, max: 261)
#
# Run: 133, exploration: 0.01, score: 296
# Scores: (min: 8, avg: 46.48, max: 296)
#
# Run: 134, exploration: 0.01, score: 357
# Scores: (min: 8, avg: 49.93, max: 357)
#
# Run: 135, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 52.34, max: 357)
#
# Run: 136, exploration: 0.01, score: 333
# Scores: (min: 8, avg: 55.57, max: 357)
#
# Run: 137, exploration: 0.01, score: 344
# Scores: (min: 8, avg: 58.91, max: 357)
#
# Run: 138, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 61.74, max: 357)
#
# Run: 139, exploration: 0.01, score: 317
# Scores: (min: 8, avg: 64.68, max: 357)
#
# Run: 140, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 66.88, max: 357)
#
# Run: 141, exploration: 0.01, score: 363
# Scores: (min: 8, avg: 70.41, max: 363)
#
# Run: 142, exploration: 0.01, score: 267
# Scores: (min: 8, avg: 72.97, max: 363)
#
# Run: 143, exploration: 0.01, score: 426
# Scores: (min: 8, avg: 77.1, max: 426)
#
# Run: 144, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 79.43, max: 426)
#
# Run: 145, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 81.47, max: 426)
#
# Run: 146, exploration: 0.01, score: 337
# Scores: (min: 8, avg: 84.76, max: 426)
#
# Run: 147, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 87.6, max: 426)
#
# Run: 148, exploration: 0.01, score: 307
# Scores: (min: 8, avg: 90.57, max: 426)
#
# Run: 149, exploration: 0.01, score: 386
# Scores: (min: 8, avg: 94.33, max: 426)
#
# Run: 150, exploration: 0.01, score: 470
# Scores: (min: 8, avg: 98.92, max: 470)
#
# Run: 151, exploration: 0.01, score: 489
# Scores: (min: 8, avg: 103.7, max: 489)
#
# Run: 152, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 106.33, max: 489)
#
# Run: 153, exploration: 0.01, score: 430
# Scores: (min: 8, avg: 110.55, max: 489)
#
# Run: 154, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 112.63, max: 489)
#
# Run: 155, exploration: 0.01, score: 421
# Scores: (min: 8, avg: 116.72, max: 489)
#
# Run: 156, exploration: 0.01, score: 462
# Scores: (min: 8, avg: 121.25, max: 489)
#
# Run: 157, exploration: 0.01, score: 318
# Scores: (min: 8, avg: 124.34, max: 489)
#
# Run: 158, exploration: 0.01, score: 283
# Scores: (min: 8, avg: 127.07, max: 489)
#
# Run: 159, exploration: 0.01, score: 321
# Scores: (min: 8, avg: 130.18, max: 489)
#
# Run: 160, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 132.73, max: 489)
#
# Run: 161, exploration: 0.01, score: 383
# Scores: (min: 8, avg: 136.46, max: 489)
#
# Run: 162, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 138.98, max: 489)
#
# Run: 163, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 141.05, max: 489)
#
# Run: 164, exploration: 0.01, score: 315
# Scores: (min: 8, avg: 144.1, max: 489)
#
# Run: 165, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 146.27, max: 489)
#
# Run: 166, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 149.08, max: 489)
#
# Run: 167, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 151.51, max: 489)
#
# Run: 168, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 154.08, max: 489)
#
# Run: 169, exploration: 0.01, score: 333
# Scores: (min: 8, avg: 157.31, max: 489)
#
# Run: 170, exploration: 0.01, score: 273
# Scores: (min: 8, avg: 159.94, max: 489)
#
# Run: 171, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 162.66, max: 489)
#
# Run: 172, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 164.89, max: 489)
#
# Run: 173, exploration: 0.01, score: 274
# Scores: (min: 8, avg: 167.53, max: 489)
#
# Run: 174, exploration: 0.01, score: 282
# Scores: (min: 8, avg: 170.24, max: 489)
#
# Run: 175, exploration: 0.01, score: 431
# Scores: (min: 8, avg: 174.45, max: 489)
#
# Run: 176, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 176.65, max: 489)
#
# Run: 177, exploration: 0.01, score: 338
# Scores: (min: 8, avg: 179.93, max: 489)
#
# Run: 178, exploration: 0.01, score: 278
# Scores: (min: 8, avg: 182.62, max: 489)
#
# Run: 179, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 184.81, max: 489)
#
# Run: 180, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 187.2, max: 489)
# Run: 181, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 188.68, max: 489)
#
# Run: 182, exploration: 0.01, score: 296
# Scores: (min: 8, avg: 191.55, max: 489)
#
# Run: 183, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 193.71, max: 489)
#
# Run: 184, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 195.7, max: 489)
#
# Solved in 84 runs, 184 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4da1cdd3f0e2> in <module>
#      88             dqn_solver.experience_replay()
#      89
# ---> 90 cartpole()
#
# <ipython-input-1-4da1cdd3f0e2> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # Explain how reinforcement learning concepts apply to the cartpole problem.
# ## What is the goal of the agent in this case?
# In the Cartpole problem, the goal of the agent is to balance a pole that is attached to a cart for as long as possible by applying forces to the cart (Surma, 2018).
#
# ## What are the various state values?
# There are 4 values in the cartpole problem:
# - The cart's position
# - The cart's velocity
# - The pole's angle
# - The pole's angular velocity
# (Surma, 2018)
#
# ## What are the possible actions that can be performed?
# There are only two actions that can be done: move the cart to the right(value of 1), and move the cart to the left(value of 0) (Gym Documentation, n.d.).
#
# ## What reinforcement algorithm is used for this problem?
# We used Q-learning to solve this problem, although it can use others. Q-learning is a type of reinforcement learning where the agent learns to make better decisions by interacting with an environment (OpenAI's Gym).
#
# # Analyze how experience replay is applied to the cartpole problem.
# ## How does experience replay work in this algorithm?
# Experience replay is the storage of the different values associated with each step in the process (DeepLizard, 2018). This means that the model can reference these in order to learn. Just like a human uses their experiences to determine their decisions.
# A (hopefully) simple breakdown of how the experience replay works with the cartpole problem: While learning, the agent applies Q-learning updates on samples of the experience. "A key reason for using replay memory is to break the correlation between consecutive samples (DeepLizard, 2018).
#
# ## What is the effect of introducing a discount factor for calculating the future rewards?
# This is what determines the importance of the rewards in the reinforcement learning. Rewards are important because, just like when training your dog, rewards help reinforce the desired behavior. A larger discount factor puts more emphasis on long-term rewards, where a lower one makes it more greedy and will attempt to get the rewards ASAP (NitinAgarwal494, 2020). Introducing a discount factor for calculating the future rewards can help in stabilizing the learning process (NitinAgarwal494, 2020; Singh, n.d.).
#
# # Analyze how neural networks are used in deep Q-learning.
# ## Explain the neural network architecture that is used in the cartpole problem.
# In our case there are, I believe, 4 neurons for the cartople problem (one for each state value, depicted by `observation_space`), and two output neurons (one for each of the actions that can be taken. There are a few layers, two that are ReLU - one of these is the input layer - and one linear.
#
# ## How does the neural network make the Q-learning algorithm more efficient?
# Accoording to Penick in his article Neural Network Q Learning, "Neural Network Q Learning has been shown to outperform traditional Q Learning algorithms in scenarios with large state spaces and complex decision-making processes. (Penick, 2023)" This means that Q-learning with a neural net is more efficient than one without.
#
# ## What difference do you see in the algorithm performance when you increase or decrease the learning rate?
# I divided the learning rate by 10 and saw a dramatic decrease in how quickly it solved the cartpole problem as compared to the original run. I believe I also attempted multiplying it by 10, but that went on for so long that I gave up on it and tried again. I believe I was sitting at over 1200 runs and over an hour and a half of it running.
#
# # References
# - *Cart Pole - gym documentation*. (n.d.). https://www.gymlibrary.dev/environments/classic_control/cart_pole/
#
# - NitinAgarwal494. (2020, April 6). *Reinforcement Learning (Q-learning) – An Introduction (Part 1)*. Data Science Central. https://www.datasciencecentral.com/reinforcement-learning-q-learning-an-introduction-part-1/
#
# - Penick, H. (2023, December 17). *Neural Network Q Learning.* Get Neural Net. https://getneuralnet.com/neural-network-q-learning/
#
# - *Replay memory explained - Experience for deep Q-Network training*. (n.d.). Deeplizard. https://deeplizard.com/learn/video/Bcuj2fTH4_4
#
# - Singh, S. (2022, October 7). *How are neural networks used in deep Q-Learning?* https://www.turing.com/kb/how-are-neural-networks-used-in-deep-q-learning
#
# - Surma, G. (2021, October 13). *Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning)*. Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
